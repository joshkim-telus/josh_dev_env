# %% [markdown]
# ### bq_import_tbl_to_df
#
# this function is used to import a bigquery table and convert to df, then write to gcs as csv

# %%
import kfp
import pandas as pd
from kfp import dsl
# from kfp.v2.dsl import (Model, Input, component)
from kfp.v2.dsl import (Artifact, Dataset, Input, InputPath, Model, Output,HTML,
                        OutputPath, ClassificationMetrics, Metrics, component)
from typing import NamedTuple
# Create Training Dataset for training pipeline

@component(
    base_image="northamerica-northeast1-docker.pkg.dev/cio-workbench-image-np-0ddefe/bi-platform/bi-aaaie/images/kfp-pycaret-slim:latest",
    output_component_file="bq_import_df.yaml",
)
def bq_import_tbl_to_df(project_id: str
              , dataset_id: str
              , table_id: str
              , region: str
              , save_data_path: str
              , token: str 
              ): 
 
    from google.cloud import bigquery
    import logging
    from datetime import datetime
    
    #### For wb
    import google.oauth2.credentials
    CREDENTIALS = google.oauth2.credentials.Credentials(token)
    
    client = bigquery.Client(project=project_id, credentials=CREDENTIALS)
    job_config = bigquery.QueryJobConfig()
    
#     #### For prod 
#     client = bigquery.Client(project=project_id)
#     job_config = bigquery.QueryJobConfig()
    
    # Change dataset / table + sp table name to version in bi-layer
    query =\
        f'''
            SELECT * FROM `{project_id}.{dataset_id}.{table_id}`
        '''
    
    df = client.query(query, job_config=job_config).to_dataframe()
    
    df.to_csv(save_data_path, index=False) 

    col_list = list([col for col in df.columns])
    
    return (col_list,)

project_id = "divg-groovyhoon-pr-d2eab4"
dataset_id = "nba_offer_targeting" 
table_id = "irpc_offer_prices"
region = "northamerica-northeast1"
save_data_path = f'gs://divg-groovyhoon-pr-d2eab4-default/NBA/{table_id}.csv'

import google.oauth2.credentials
token = !gcloud auth print-access-token
token_str = token[0]

bq_import_tbl_to_df(project_id, dataset_id, table_id, region, save_data_path, token_str)

# %% [markdown]
# ### COMPLETED & READY
#
# ### bq_import_tbl_to_df (KFP component)
#
# this component is used to import a bigquery table and convert to df, then write to gcs as csv

# %%
import kfp
import pandas as pd
from kfp import dsl
# from kfp.v2.dsl import (Model, Input, component)
from kfp.v2.dsl import (Artifact, Dataset, Input, InputPath, Model, Output,HTML,
                        OutputPath, ClassificationMetrics, Metrics, component)
from typing import NamedTuple
# Create Training Dataset for training pipeline

@component(
    base_image="northamerica-northeast1-docker.pkg.dev/cio-workbench-image-np-0ddefe/bi-platform/bi-aaaie/images/kfp-pycaret-slim:latest",
    output_component_file="bq_import_tbl_to_df.yaml",
)
def bq_import_tbl_to_df(project_id: str
              , dataset_id: str
              , table_id: str
              , region: str
              , save_data_path: str
              , token: str 
              ):
 
    from google.cloud import bigquery
    import logging
    from datetime import datetime
    
    #### For wb
    import google.oauth2.credentials
    CREDENTIALS = google.oauth2.credentials.Credentials(token)
    
    client = bigquery.Client(project=project_id, credentials=CREDENTIALS)
    job_config = bigquery.QueryJobConfig()
    
#     #### For prod 
#     client = bigquery.Client(project=project_id)
#     job_config = bigquery.QueryJobConfig()
    
    # Change dataset / table + sp table name to version in bi-layer
    query =\
        f'''
            SELECT * FROM `{project_id}.{dataset_id}.{table_id}`
        '''
    
    df = client.query(query, job_config=job_config).to_dataframe()
    
    df.to_csv(save_data_path, index=False) 

    col_list = list([col for col in df.columns])
    
    return (col_list,)

# %% [markdown]
# ### bq_import_tbl_to_df (Python Function)
#
# this function is used to import a bigquery table and convert to df, then write to gcs as csv

# %%
def bq_import_tbl_to_df(project_id: str
              , dataset_id: str
              , table_id: str
              , region: str
              , save_data_path: str
              , token: str 
              ): 
    
    from google.cloud import bigquery
    import logging
    from datetime import datetime
    
    #### For wb
    import google.oauth2.credentials
    CREDENTIALS = google.oauth2.credentials.Credentials(token)
    
    client = bigquery.Client(project=project_id, credentials=CREDENTIALS)
    job_config = bigquery.QueryJobConfig()
    
#     #### For prod 
#     client = bigquery.Client(project=project_id)
#     job_config = bigquery.QueryJobConfig()
    
    # Change dataset / table + sp table name to version in bi-layer
    query =\
        f'''
            SELECT * FROM `{project_id}.{dataset_id}.{table_id}`
        '''
    
    df = client.query(query, job_config=job_config).to_dataframe()
    
    df.to_csv(save_data_path, index=False) 

#     col_list = list([col for col in df.columns])
    
#     return (col_list,)

import google.oauth2.credentials
token = !gcloud auth print-access-token
token_str = token[0]

##### digital 1p

project_id = "divg-groovyhoon-pr-d2eab4"
dataset_id = "nba_offer_targeting" 
table_id = "bq_irpc_digital_1p_base"
region = "northamerica-northeast1"
save_data_path = f'gs://divg-groovyhoon-pr-d2eab4-default/uploads/{table_id}.csv'
token = token_str

bq_import_tbl_to_df(project_id, dataset_id, table_id, region, save_data_path, token)


project_id = "divg-groovyhoon-pr-d2eab4"
dataset_id = "nba_offer_targeting" 
table_id = "irpc_offer_1p_plans"
region = "northamerica-northeast1"
save_data_path = f'gs://divg-groovyhoon-pr-d2eab4-default/uploads/{table_id}.csv'
token = token_str

bq_import_tbl_to_df(project_id, dataset_id, table_id, region, save_data_path, token)


project_id = "divg-groovyhoon-pr-d2eab4"
dataset_id = "nba_offer_targeting" 
table_id = "irpc_offer_prices"
region = "northamerica-northeast1"
save_data_path = f'gs://divg-groovyhoon-pr-d2eab4-default/uploads/{table_id}.csv'
token = token_str

bq_import_tbl_to_df(project_id, dataset_id, table_id, region, save_data_path, token)


##### digital 2p

project_id = "divg-groovyhoon-pr-d2eab4"
dataset_id = "nba_offer_targeting" 
table_id = "bq_irpc_digital_2p_base"
region = "northamerica-northeast1"
save_data_path = f'gs://divg-groovyhoon-pr-d2eab4-default/uploads/{table_id}.csv'
token = token_str

bq_import_tbl_to_df(project_id, dataset_id, table_id, region, save_data_path, token)


project_id = "divg-groovyhoon-pr-d2eab4"
dataset_id = "nba_offer_targeting" 
table_id = "irpc_offer_2p_plans"
region = "northamerica-northeast1"
save_data_path = f'gs://divg-groovyhoon-pr-d2eab4-default/uploads/{table_id}.csv'
token = token_str

bq_import_tbl_to_df(project_id, dataset_id, table_id, region, save_data_path, token)


##### casa

project_id = "divg-groovyhoon-pr-d2eab4"
dataset_id = "nba_offer_targeting"
table_id = "bq_irpc_casa_base"
region = "northamerica-northeast1"
save_data_path = f'gs://divg-groovyhoon-pr-d2eab4-default/uploads/{table_id}.csv'
token = token_str

bq_import_tbl_to_df(project_id, dataset_id, table_id, region, save_data_path, token)

# %% [markdown]
# 1. bq_import_tbl_to_df
# - read bq_irpc_digital_1p_base
# - write to gcs as csv (bq_irpc_digital_1p_base.csv)
#
# project_id = "divg-groovyhoon-pr-d2eab4"
# dataset_id = "nba_offer_targeting"
# table_id = "irpc_offer_prices"
# region = "northamerica-northeast1"
# save_data_path = f'gs://divg-groovyhoon-pr-d2eab4-default/NBA/{table_id}.csv'
#
# 2. bq_import_tbl_to_df
# - read irpc_offer_1p_plans
# - write to gcs as csv (irpc_offer_1p_plans.csv)!
#
# project_id = "divg-groovyhoon-pr-d2eab4"
# dataset_id = "nba_offer_targeting"
# table_id = "irpc_offer_prices"
# region = "northamerica-northeast1"
# save_data_path = f'gs://divg-groovyhoon-pr-d2eab4-default/NBA/{table_id}.csv'
#
# 3. bq_import_tbl_to_df
# - read irpc_offer_prices
# - write to gcs as csv (irpc_offer_prices.csv)
#
# project_id = "divg-groovyhoon-pr-d2eab4"
# dataset_id = "nba_offer_targeting"
# table_id = "irpc_offer_prices"
# region = "northamerica-northeast1"
# save_data_path = f'gs://divg-groovyhoon-pr-d2eab4-default/NBA/{table_id}.csv'
#
# 4. bq_irpc_offers
# - read the above 3 csv's (bq_irpc_digital_1p_base.csv, irpc_offer_1p_plans.csv, irpc_offer_prices.csv
# - read bq_irpc_digital_1p_base and store in df
# - convert irpc_offer_1p_plans and irpc_offer_prices to lists and dictionaries
#     - list_hsia_speed_1p
#     - dict_hsia_details_1p
# - determine offers 1, 2, 3 using the lists and dictionaries created
# - attach "Category", "Subcategory", "rpp_hsia_end_dt", "ASSMT_VALID_START_TS", "ASSMT_VALID_END_TS", "rk" to 3 offers
# - ***pay attention to the rows that have "None" values in the promo_seg1, promo_seg2, promo_seg3
# - concatenate concatenate digital_1p_reco1 + digital_1p_reco2 + digital_1p_reco3
# - write .csv to gcs (digital_1p_base_irpc_offers.csv)

# %%
df.head()

# %%
import pandas as pd 
import numpy as np 

df = pd.read_csv('gs://divg-groovyhoon-pr-d2eab4-default/uploads/irpc_offer_prices.csv') 

print(df.iloc[:4])

# %% [markdown]
# ### COMPLETED & READY
#
# ### convert_df_to_list_dict()
#
# this function accepts a pandas dataframe as an input and returns list_hsias_speed and dict_hsia_details as outputs

# %%
def convert_df_to_list_dict(df
              , channel: str = 'digital' # digital or casa
              ): 
 
    import re
    import logging 
    from datetime import datetime

    # Change dataset / table + sp table name to version in bi-layer
    if channel == 'digital': 
        df = df
    elif channel == 'casa': 
        df = df.iloc[:4]
    else: 
        print("a parameter 'channel' can only be either 'digital' or 'casa'""")
   
    # create list_hsia_speed = [250, 500, 1000, 1500, 3000]
    list_hsia_speed = df.columns[3:]
    list_hsia_speed = [int(re.search(r'\d+', speed).group()) for speed in list_hsia_speed]

    # create dictionary of hsia_prices 
    # Convert DataFrame to a dictionary
    dict_hsia_details = df.to_dict(orient='list')

    # Function to remove <NA> values from a list
    def remove_na_from_list(lst):
        return [value for value in lst if not pd.isna(value)]

    # Remove <NA> values from all lists in the dictionary
    dict_hsia_details = {key: remove_na_from_list(value) for key, value in dict_hsia_details.items()}

    return list_hsia_speed, dict_hsia_details

import pandas as pd 
import numpy as np 

import google.oauth2.credentials
token = !gcloud auth print-access-token
token_str = token[0]

from google.cloud import bigquery
import logging
from datetime import datetime
import re

#### For wb
import google.oauth2.credentials
CREDENTIALS = google.oauth2.credentials.Credentials(token_str)

project_id = "divg-groovyhoon-pr-d2eab4"
dataset_id = "nba_offer_targeting" 
table_id = "irpc_offer_prices"
region = "northamerica-northeast1"

client = bigquery.Client(project=project_id, credentials=CREDENTIALS)
job_config = bigquery.QueryJobConfig()

#     #### For prod 
#     client = bigquery.Client(project=project_id)
#     job_config = bigquery.QueryJobConfig()

# Change dataset / table + sp table name to version in bi-layer
query =\
    f'''
        SELECT * FROM `{project_id}.{dataset_id}.{table_id}`
    '''

df = client.query(query, job_config=job_config).to_dataframe()

list_hsia_speed, dict_hsia_details = convert_df_to_list_dict(df, 'digital')

print(dict_hsia_details)

# %% [markdown]
# ### 4. offer_attachment
# - read the above 3 csv's (bq_irpc_digital_1p_base.csv, irpc_offer_1p_plans.csv, irpc_offer_prices.csv
# - read bq_irpc_digital_1p_base and store in df
# - convert irpc_offer_1p_plans and irpc_offer_prices to lists and dictionaries
# 	- list_hsia_speed_1p
# 	- dict_hsia_details_1p
# - attach offers 1, 2, 3 to each customer based on current speed, price, and max provisioned speed eligibility (using the lists and dictionaries created)
# - write df_base with offers attached to gcs as a csv file

# %%
# import kfp
# import pandas as pd
# from kfp import dsl
# # from kfp.v2.dsl import (Model, Input, component)
# from kfp.v2.dsl import (Artifact, Dataset, Input, InputPath, Model, Output,HTML,
#                         OutputPath, ClassificationMetrics, Metrics, component)
# from typing import NamedTuple

# @component(
#     base_image="northamerica-northeast1-docker.pkg.dev/cio-workbench-image-np-0ddefe/bi-platform/bi-aaaie/images/kfp-pycaret-slim:latest",
#     output_component_file="bq_irpc_offers.yaml",
# )

def offer_attachment(irpc_base_csv: str
                   , irpc_offer_plans_csv: str 
                   , irpc_offer_prices_csv: str
                   , channel: str
                   , save_data_path: str
                  ): 
    import pandas as pd 
    import numpy as np 

    def convert_df_to_list_dict(df, 
                                channel: str = 'digital' # digital or casa
                                ): 

        import re
        import logging 
        from datetime import datetime

        print(df.head())

        # Change dataset / table + sp table name to version in bi-layer
        if channel == 'digital': 
            df = df
        elif channel == 'casa': 
            df = df.iloc[:4]
        else: 
            print("a parameter 'channel' can only be either 'digital' or 'casa'")

        # create list_hsia_speed = [250, 500, 1000, 1500, 3000]
        list_hsia_speed = df.columns[3:]

        print(list_hsia_speed)

        list_hsia_speed = [int(re.search(r'\d+', speed).group()) for speed in list_hsia_speed]

        # create dictionary of hsia_prices 
        # Convert DataFrame to a dictionary
        dict_hsia_details = df.to_dict(orient='list')

        return list_hsia_speed, dict_hsia_details

    def find_digital_irpc_offers(list_hsia_speed: str, # list_hsia_speed = [250, 500, 1000, 1500, 3000] as of Feb 2024
                         dict_hsia_plans_details: str, # e.g. internet_250: ['1P:Regular (Internet 250)', '1P:Tier 0 (Internet 250)', '1P:Tier 1 (Internet 250)']
                         dict_hsia_prices_details: str, # e.g. internet_250: [105, 100, 95, 85, 75]
                         provisioned_hs_speed_numeric, # customer's current internet speed
                         hs_max_speed_numeric, # customer's eligible max internet speed
                         total_charges, # current internet amt
                         offer_1_ind = True 
                         ):

        import pandas as pd
        import numpy as np 

        if provisioned_hs_speed_numeric is None and hs_max_speed_numeric is None and total_charges is None: 
            return [None, None, None, None]

        ### 1. Find the smallest number in hsia_speed that is greater than provisioned_hs_speed_numeric

        # exception: if the current hsia_speed >= 150 AND hsia_speed < 500, then change the value to 499 so that it bypasses 250 
        ## Internet 150 customers should not be shown Internet 250 tier, as they are upsped in the backend to speeds of 300mbps ##
        if provisioned_hs_speed_numeric >= 150 and provisioned_hs_speed_numeric < 500: 
            provisioned_hs_speed_numeric = 499
            
        # It doesn't make sense when hs_max_speed_numeric < provisioned_hs_speed_numeric. 
        # Update hs_max_speed_numeric to provisioned_hs_speed_numeric when it's the case. 
        if hs_max_speed_numeric < provisioned_hs_speed_numeric: 
            hs_max_speed_numeric = provisioned_hs_speed_numeric

        # store minimum hsia speed offer available greater than (or equal to) the current speed in 'hsia_speed'
        # AND 
        # minimum speed offer available where the highest offer price in that speed is greater than or equal to 'total_charges'

        # requirements:
            # - list_hsia_speed
            # - np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)]) --> max offer price in the internet speed
            # - compare max offer price vs total_charges 
            # - since internet_250 does not have offer tier equal to or greater than $125, we need to move on to the next speed, which is 500
            # - since internet_500 does not have offer tier equal to or greater than $125, we need to again move on to the next speed, which is 1000
            # - internet_1000 has an offer tier equal to or greater than $125, so hsia_speed = 1000

        try: 
            if offer_1_ind == True: 
                hsia_speed = np.min([spd for spd in list_hsia_speed if spd >= provisioned_hs_speed_numeric and spd <= hs_max_speed_numeric and not pd.isna(spd)]) # --> 250
            else: 
                hsia_speed = np.min([spd for spd in list_hsia_speed if spd > provisioned_hs_speed_numeric and spd <= hs_max_speed_numeric and not pd.isna(spd)])

            max_offer_price = np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)])

        except ValueError: 
            return [None, None, None, None]

        try: 
            while max_offer_price < total_charges: 
                hsia_speed_idx = list_hsia_speed.index(hsia_speed)
                hsia_speed = list_hsia_speed[hsia_speed_idx + 1]
                max_offer_price = np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)])

        except IndexError: 
            print("This customer is currently paying > $145, thus not eligible for any offers")

        ### 2. Find the smallest number in dict_hsia_prices_details[hsia_speed] that is greater (or equal to) than total_charges --> 75

        list_hsia_price = dict_hsia_prices_details[f'internet_{hsia_speed}']

        if len([price for price in list_hsia_price if price >= total_charges]) > 0: 
            if offer_1_ind == True: 
                hsia_price = np.min([price for price in list_hsia_price if price >= total_charges])
            else: 
                hsia_price = np.min([price for price in list_hsia_price if price > total_charges])

            try: 
                # scenario when the same price DOES EXIST in the next speed offer (e.g. if internet_500, check internet_1000 for $95 offer ==> YES): 
                hsia_speed_idx = list_hsia_speed.index(hsia_speed)
                next_hsia_speed = list_hsia_speed[hsia_speed_idx + 1]

                if hsia_price in dict_hsia_prices_details[f'internet_{next_hsia_speed}'] and hsia_speed == provisioned_hs_speed_numeric: 
                    list_hsia_price = dict_hsia_prices_details[f'internet_{next_hsia_speed}']
                    hsia_speed = next_hsia_speed 

            except IndexError: 
                print("The hsia_speed {hsia_speed} is the fastest internet speed available.")

            except UnboundLocalError: 
                print("The hsia_speed {hsia_speed} is the fastest internet speed available.")

            # scenario when the same price DOES NOT EXIST in the next speed offer (e.g. if internet_1000, check internet_1500 for $95 offer ==> NO): 

            if hsia_price in list_hsia_price:
                plan_idx = list_hsia_price.index(hsia_price)    

            ### 4. Call the plan name by hsia_plans[provisioned_hs_speed_numeric]==250][plan_idx==4] --> "1P: Tier 3 (Internet 250)"

            hsia_plan_name = dict_hsia_plans_details[f'internet_{hsia_speed}'][plan_idx]

            return [hsia_speed, hs_max_speed_numeric, hsia_price, hsia_plan_name] 

        else: 

            return [None, None, None, None]

    # read the above 3 csv's (bq_irpc_digital_1p_base.csv, irpc_offer_1p_plans.csv, irpc_offer_prices.csv
    # read bq_irpc_digital_1p_base and store in df
    df_base = pd.read_csv(irpc_base_csv)
    df_plans = pd.read_csv(irpc_offer_plans_csv)
    df_prices = pd.read_csv(irpc_offer_prices_csv)
    
    # convert irpc_offer_1p_plans and irpc_offer_prices to lists and dictionaries
    # - list_hsia_speed
    # - dict_hsia_details
    list_hsia_speed, dict_hsia_plans_details = convert_df_to_list_dict(df_plans, channel)
    list_hsia_speed, dict_hsia_prices_details = convert_df_to_list_dict(df_prices, channel)
    
    offer_1_list, offer_2_list, offer_3_list = [] , [], [] 

    for idx, row in df_base.iterrows():
        
        print(row['bacct_num'])
        
        provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges = row['provisioned_hs_speed_numeric'], row['hs_max_speed_numeric'], row['total_charges']

        offer_1_hsia_speed, offer_1_hs_max_speed_numeric, offer_1_hsia_price, offer_1_hsia_plan_name = find_digital_irpc_offers(list_hsia_speed, 
                                                                                                                        dict_hsia_plans_details, 
                                                                                                                        dict_hsia_prices_details, 
                                                                                                                        provisioned_hs_speed_numeric, 
                                                                                                                        hs_max_speed_numeric, 
                                                                                                                        total_charges, 
                                                                                                                        True) 
        
        offer_2_hsia_speed, offer_2_hs_max_speed_numeric, offer_2_hsia_price, offer_2_hsia_plan_name = find_digital_irpc_offers(list_hsia_speed, 
                                                                                                                        dict_hsia_plans_details,
                                                                                                                        dict_hsia_prices_details,
                                                                                                                        offer_1_hsia_speed,
                                                                                                                        offer_1_hs_max_speed_numeric,
                                                                                                                        offer_1_hsia_price,
                                                                                                                        False) 
        
        # for casa, add a rule to attach L4L offer first, if available
        # otherwise, attach offer 3 as is
        offer_3_hsia_speed, offer_3_hs_max_speed_numeric, offer_3_hsia_price, offer_3_hsia_plan_name = find_digital_irpc_offers(list_hsia_speed,
                                                                                                                        dict_hsia_plans_details,
                                                                                                                        dict_hsia_prices_details,
                                                                                                                        offer_2_hsia_speed,
                                                                                                                        offer_2_hs_max_speed_numeric,
                                                                                                                        offer_2_hsia_price,
                                                                                                                        False) 
        
        offer_1_list.append(offer_1_hsia_plan_name)
        offer_2_list.append(offer_2_hsia_plan_name)
        offer_3_list.append(offer_3_hsia_plan_name)

    df_base['promo_seg1'] = offer_1_list
    df_base['promo_seg2'] = offer_2_list
    df_base['promo_seg3'] = offer_3_list

    df_base.to_csv(save_data_path)
    
irpc_base_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/uploads/bq_irpc_digital_1p_base.csv'
irpc_offer_plans_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/uploads/irpc_offer_1p_plans.csv'
irpc_offer_prices_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/uploads/irpc_offer_prices.csv'
    
offer_attachment(irpc_base_csv, irpc_offer_plans_csv, irpc_offer_prices_csv, 'digital', 'gs://divg-groovyhoon-pr-d2eab4-default/uploads/irpc_digital_1p_base_with_offers.csv')

# %% [markdown]
# ### 4. irpc digital offer_attachment (lambda)
# - read the above 3 csv's (bq_irpc_digital_1p_base.csv, irpc_offer_1p_plans.csv, irpc_offer_prices.csv
# - read bq_irpc_digital_1p_base and store in df
# - convert irpc_offer_1p_plans and irpc_offer_prices to lists and dictionaries
# 	- list_hsia_speed_1p
# 	- dict_hsia_details_1p
# - attach offers 1, 2, 3 to each customer based on current speed, price, and max provisioned speed eligibility (using the lists and dictionaries created)
# - write df_base with offers attached to gcs as a csv file

# %%
# import kfp
# import pandas as pd
# from kfp import dsl
# # from kfp.v2.dsl import (Model, Input, component)
# from kfp.v2.dsl import (Artifact, Dataset, Input, InputPath, Model, Output,HTML,
#                         OutputPath, ClassificationMetrics, Metrics, component)
    # from typing import NamedTuple

# @component(
#     base_image="northamerica-northeast1-docker.pkg.dev/cio-workbench-image-np-0ddefe/bi-platform/bi-aaaie/images/kfp-pycaret-slim:latest",
#     output_component_file="bq_irpc_offers.yaml",
# )

def offer_attachment_digital(irpc_base_csv: str
                   , irpc_offer_plans_csv: str 
                   , irpc_offer_prices_csv: str
                   , channel: str
                   , save_data_path: str
                  ): 
    
    import pandas as pd 
    import numpy as np 

    def convert_df_to_list_dict(df, 
                                channel: str = 'digital' # digital or casa
                                ): 

        import re
        import logging 
        from datetime import datetime

        # Change dataset / table + sp table name to version in bi-layer
        if channel == 'digital': 
            df = df
        elif channel == 'casa': 
            df = df.iloc[:4]
        else: 
            print("a parameter 'channel' can only be either 'digital' or 'casa'")

        # create list_hsia_speed = [250, 500, 1000, 1500, 3000]
        list_hsia_speed = df.columns[3:]

        list_hsia_speed = [int(re.search(r'\d+', speed).group()) for speed in list_hsia_speed]

        # create dictionary of hsia_prices 
        # Convert DataFrame to a dictionary
        dict_hsia_details = df.to_dict(orient='list')

        return list_hsia_speed, dict_hsia_details

    def find_digital_irpc_offers(list_hsia_speed: str, # list_hsia_speed = [250, 500, 1000, 1500, 3000] as of Feb 2024
                             dict_hsia_plans_details: str, # e.g. internet_250: ['1P:Regular (Internet 250)', '1P:Tier 0 (Internet 250)', '1P:Tier 1 (Internet 250)']
                             dict_hsia_prices_details: str, # e.g. internet_250: [105, 100, 95, 85, 75]
                             row, 
                             offer_num: int
                             ):

        import pandas as pd
        import numpy as np 
        
        cust_id, ban, lpds_id = row['cust_id'], row['bacct_num'], row['lpds_id']
        
        if offer_num == 1: 
            provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges = row['provisioned_hs_speed_numeric'], row['hs_max_speed_numeric'], row['total_charges']
        elif offer_num == 2: 
            provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges = row['hsia_speed1'], row['hs_max_speed_numeric1'], row['hsia_price1']
        elif offer_num == 3: 
            provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges = row['hsia_speed2'], row['hs_max_speed_numeric2'], row['hsia_price2']
        
        if provisioned_hs_speed_numeric is None and hs_max_speed_numeric is None and total_charges is None: 
            return [None, None, None, None]

        ### 1. Find the smallest number in hsia_speed that is greater than provisioned_hs_speed_numeric

        # exception: if the current hsia_speed >= 150 AND hsia_speed < 500, then change the value to 499 so that it bypasses 250 
        ## Internet 150 customers should not be shown Internet 250 tier, as they are upsped in the backend to speeds of 300mbps ##
        if provisioned_hs_speed_numeric >= 150 and provisioned_hs_speed_numeric < 500: 
            provisioned_hs_speed_numeric = 499
            
        # It doesn't make sense when hs_max_speed_numeric < provisioned_hs_speed_numeric. 
        # Update hs_max_speed_numeric to provisioned_hs_speed_numeric when it's the case. 
        if hs_max_speed_numeric < provisioned_hs_speed_numeric: 
            hs_max_speed_numeric = provisioned_hs_speed_numeric

        # store minimum hsia speed offer available greater than (or equal to) the current speed in 'hsia_speed'
        # AND 
        # minimum speed offer available where the highest offer price in that speed is greater than or equal to 'total_charges'

        # requirements:
            # - list_hsia_speed
            # - np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)]) --> max offer price in the internet speed
            # - compare max offer price vs total_charges 
            # - since internet_250 does not have offer tier equal to or greater than $125, we need to move on to the next speed, which is 500
            # - since internet_500 does not have offer tier equal to or greater than $125, we need to again move on to the next speed, which is 1000
            # - internet_1000 has an offer tier equal to or greater than $125, so hsia_speed = 1000

        try: 
            if offer_num == 1: 
                hsia_speed = np.min([spd for spd in list_hsia_speed if spd >= provisioned_hs_speed_numeric and spd <= hs_max_speed_numeric and not pd.isna(spd)]) # --> 250
            else: 
                hsia_speed = np.min([spd for spd in list_hsia_speed if spd > provisioned_hs_speed_numeric and spd <= hs_max_speed_numeric and not pd.isna(spd)])

            max_offer_price = np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)])

        except ValueError: 
            return [None, None, None, None]

        try: 
            while max_offer_price < total_charges: 
                hsia_speed_idx = list_hsia_speed.index(hsia_speed)
                hsia_speed = list_hsia_speed[hsia_speed_idx + 1]
                max_offer_price = np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)])

        except IndexError: 
            print(f"The customer {cust_id} {ban} {lpds_id} is currently paying > $145, thus not eligible for any offers")

        ### 2. Find the smallest number in dict_hsia_prices_details[hsia_speed] that is greater (or equal to) than total_charges --> 75

        list_hsia_price = dict_hsia_prices_details[f'internet_{hsia_speed}']

        if len([price for price in list_hsia_price if price >= total_charges]) > 0: 
            
            try: 
                if offer_num == 1: 
                    hsia_price = np.min([price for price in list_hsia_price if price >= total_charges])
                else: 
                    hsia_price = np.min([price for price in list_hsia_price if price > total_charges])
                    
            except ValueError: 
                return [None, None, None, None]

            try: 
                # scenario when the same price DOES EXIST in the next speed offer (e.g. if internet_500, check internet_1000 for $95 offer ==> YES): 
                hsia_speed_idx = list_hsia_speed.index(hsia_speed)
                next_hsia_speed = list_hsia_speed[hsia_speed_idx + 1]

                if hsia_price in dict_hsia_prices_details[f'internet_{next_hsia_speed}'] and hsia_speed == provisioned_hs_speed_numeric: 
                    list_hsia_price = dict_hsia_prices_details[f'internet_{next_hsia_speed}']
                    hsia_speed = next_hsia_speed 

            except IndexError: 
                print(f"For {cust_id} {ban} {lpds_id}, the hsia_speed {hsia_speed} is the fastest internet speed available.")

            except UnboundLocalError: 
                print(f"For {cust_id} {ban} {lpds_id}, the hsia_speed {hsia_speed} is the fastest internet speed available.")

            # scenario when the same price DOES NOT EXIST in the next speed offer (e.g. if internet_1000, check internet_1500 for $95 offer ==> NO): 

            if hsia_price in list_hsia_price:
                plan_idx = list_hsia_price.index(hsia_price)    

            ### 4. Call the plan name by hsia_plans[provisioned_hs_speed_numeric]==250][plan_idx==4] --> "1P: Tier 3 (Internet 250)"

            hsia_plan_name = dict_hsia_plans_details[f'internet_{hsia_speed}'][plan_idx]

            return [hsia_speed, hs_max_speed_numeric, hsia_price, hsia_plan_name] 

        else: 

            return [None, None, None, None]

    # read the above 3 csv's (bq_irpc_digital_1p_base.csv, irpc_offer_1p_plans.csv, irpc_offer_prices.csv
    # read bq_irpc_digital_1p_base and store in df
    df_base = pd.read_csv(irpc_base_csv)
    df_plans = pd.read_csv(irpc_offer_plans_csv)
    df_prices = pd.read_csv(irpc_offer_prices_csv)
    
    # convert irpc_offer_1p_plans and irpc_offer_prices to lists and dictionaries
    # - list_hsia_speed
    # - dict_hsia_details
    list_hsia_speed, dict_hsia_plans_details = convert_df_to_list_dict(df_plans, channel)
    list_hsia_speed, dict_hsia_prices_details = convert_df_to_list_dict(df_prices, channel)
    
    offer_1_list, offer_2_list, offer_3_list = [] , [], [] 

    df_base[['hsia_speed1', 'hs_max_speed_numeric1', 'hsia_price1', 'promo_seg1']]  = df_base.apply(lambda row: pd.Series(find_digital_irpc_offers(list_hsia_speed, dict_hsia_plans_details, dict_hsia_prices_details, row, 1)), axis=1)
    df_base[['hsia_speed2', 'hs_max_speed_numeric2', 'hsia_price2', 'promo_seg2']]  = df_base.apply(lambda row: pd.Series(find_digital_irpc_offers(list_hsia_speed, dict_hsia_plans_details, dict_hsia_prices_details, row, 2)), axis=1)
    df_base[['hsia_speed3', 'hs_max_speed_numeric3', 'hsia_price3', 'promo_seg3']]  = df_base.apply(lambda row: pd.Series(find_digital_irpc_offers(list_hsia_speed, dict_hsia_plans_details, dict_hsia_prices_details, row, 3)), axis=1)
    
    df_base = df_base[['cust_id', 'bacct_num', 'fms_address_id', 'lpds_id', 'candate', 'OPTIK_TV_IND', 'HSIA_IND', 'hs_max_speed_numeric', 'provisioned_hs_speed_numeric', 
                       'rpp_hsia_end_dt', 'rpp_ttv_end_dt', 'total_charges', 'promo_seg1', 'promo_seg2', 'promo_seg3']] 
    
    df_base.to_csv(save_data_path)
    
irpc_base_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/nba_offer_targeting/bq_irpc_digital_1p_base.csv'
irpc_offer_plans_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/nba_offer_targeting/irpc_offer_1p_plans.csv'
irpc_offer_prices_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/nba_offer_targeting/irpc_offer_prices.csv'
    
offer_attachment_digital(irpc_base_csv, irpc_offer_plans_csv, irpc_offer_prices_csv, 'digital', 'gs://divg-groovyhoon-pr-d2eab4-default/uploads/irpc_digital_1p_base_with_offers_nb.csv')

# %%
error

# %% [markdown]
# ### 4. irpc casa offer_attachment (lambda)
# - read the above 3 csv's (bq_irpc_digital_1p_base.csv, irpc_offer_1p_plans.csv, irpc_offer_prices.csv
# - read bq_irpc_digital_1p_base and store in df
# - convert irpc_offer_1p_plans and irpc_offer_prices to lists and dictionaries
# 	- list_hsia_speed_1p
# 	- dict_hsia_details_1p
# - attach offers 1, 2, 3 to each customer based on current speed, price, and max provisioned speed eligibility (using the lists and dictionaries created)
# - write df_base with offers attached to gcs as a csv file

# %%
# import kfp
# import pandas as pd
# from kfp import dsl
# # from kfp.v2.dsl import (Model, Input, component)
# from kfp.v2.dsl import (Artifact, Dataset, Input, InputPath, Model, Output,HTML,
#                         OutputPath, ClassificationMetrics, Metrics, component)
    # from typing import NamedTuple

# @component(
#     base_image="northamerica-northeast1-docker.pkg.dev/cio-workbench-image-np-0ddefe/bi-platform/bi-aaaie/images/kfp-pycaret-slim:latest",
#     output_component_file="bq_irpc_offers.yaml",
# )

def offer_attachment_casa(irpc_base_csv: str
                   , irpc_offer_plans_csv: str 
                   , irpc_offer_prices_csv: str
                   , channel: str
                   , save_data_path: str
                  ): 
    import pandas as pd 
    import numpy as np 

    def convert_df_to_list_dict(df, 
                                channel: str = 'digital' # digital or casa
                                ): 

        import re
        import logging 
        from datetime import datetime

        print(df.head())

        # Change dataset / table + sp table name to version in bi-layer
        if channel == 'digital': 
            df = df
        elif channel == 'casa': 
            df = df.iloc[:4]
        else: 
            print("a parameter 'channel' can only be either 'digital' or 'casa'")

        # create list_hsia_speed = [250, 500, 1000, 1500, 3000]
        list_hsia_speed = df.columns[3:]

        print(list_hsia_speed)

        list_hsia_speed = [int(re.search(r'\d+', speed).group()) for speed in list_hsia_speed]

        # create dictionary of hsia_prices 
        # Convert DataFrame to a dictionary
        dict_hsia_details = df.to_dict(orient='list')

        return list_hsia_speed, dict_hsia_details

    def find_casa_irpc_offers(list_hsia_speed: str, # list_hsia_speed = [250, 500, 1000, 1500, 3000] as of Feb 2024
                             dict_hsia_plans_details: str, # e.g. internet_250: ['1P:Regular (Internet 250)', '1P:Tier 0 (Internet 250)', '1P:Tier 1 (Internet 250)']
                             dict_hsia_prices_details: str, # e.g. internet_250: [105, 100, 95, 85, 75]
                             row, 
                             offer_num: int
                             ):

        import pandas as pd
        import numpy as np 
        
        cust_id, ban, lpds_id = row['cust_id'], row['bacct_num'], row['lpds_id']
        
        if offer_num == 1: 
            provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges = row['provisioned_hs_speed_numeric'], row['hs_max_speed_numeric'], row['total_charges']
        elif offer_num == 2: 
            provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges = row['hsia_speed1'], row['hs_max_speed_numeric1'], row['hsia_price1']
        elif offer_num == 3: 
            provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges = row['provisioned_hs_speed_numeric'], row['hs_max_speed_numeric'], row['total_charges']
        
        if provisioned_hs_speed_numeric is None and hs_max_speed_numeric is None and total_charges is None: 
            return [None, None, None, None] 

        ### 1. Find the smallest number in hsia_speed that is greater than provisioned_hs_speed_numeric
        # exception: if the current hsia_speed >= 150 AND hsia_speed < 500, then change the value to 499 so that it bypasses 250 
        ## Internet 150 customers should not be shown Internet 250 tier, as they are upsped in the backend to speeds of 300mbps ##
        if provisioned_hs_speed_numeric >= 150 and provisioned_hs_speed_numeric < 500: 
            provisioned_hs_speed_numeric = 499

        # if offer_3_ind == True: 
        # find an L4L offer - lowest speed tier possible at equal or higher than their current pay
        # Lower speed tier than offer 1
        # Can also be in-market rack rate
        
        if offer_num == 3:

            try: 

                hsia_speed = np.min([spd for spd in list_hsia_speed if spd == provisioned_hs_speed_numeric and spd <= hs_max_speed_numeric and not pd.isna(spd)])

                list_hsia_price = dict_hsia_prices_details[f'internet_{hsia_speed}']

                if len([price for price in list_hsia_price if price >= total_charges]) > 0:
                    hsia_price = np.min([price for price in list_hsia_price if price > total_charges])

                if hsia_price in list_hsia_price:
                    plan_idx = list_hsia_price.index(hsia_price)

                hsia_plan_name = dict_hsia_plans_details[f'internet_{hsia_speed}'][plan_idx]

                return [hsia_speed, hs_max_speed_numeric, hsia_price, hsia_plan_name]

            except IndexError:
                provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges = row['hsia_speed2'], row['hs_max_speed_numeric2'], row['hsia_price2']

            except ValueError: 
                provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges = row['hsia_speed2'], row['hs_max_speed_numeric2'], row['hsia_price2']
                
            except UnboundLocalError: 
                provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges = row['hsia_speed2'], row['hs_max_speed_numeric2'], row['hsia_price2']
        
        # store minimum hsia speed offer available greater than the current speed in 'hsia_speed'
        # AND 
        # minimum speed offer available where the highest offer price in that speed is greater than or equal to 'total_charges'

        # requirements:
            # - list_hsia_speed
            # - np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)]) --> max offer price in the internet speed
            # - compare max offer price vs total_charges 
            # - since internet_250 does not have offer tier equal to or greater than $125, we need to move on to the next speed, which is 500
            # - since internet_500 does not have offer tier equal to or greater than $125, we need to again move on to the next speed, which is 1000
            # - internet_1000 has an offer tier equal to or greater than $125, so hsia_speed = 1000

        try: 

            hsia_speed = np.min([spd for spd in list_hsia_speed if spd > provisioned_hs_speed_numeric and spd <= hs_max_speed_numeric and not pd.isna(spd)])
            max_offer_price = np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)])
            
            while max_offer_price < total_charges: 
                hsia_speed_idx = list_hsia_speed.index(hsia_speed)
                hsia_speed = list_hsia_speed[hsia_speed_idx + 1]
                max_offer_price = np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)])

        except IndexError:
            pass

        except ValueError: 
            return [None, None, None, None]

        ### 2. Find the smallest number in dict_hsia_prices_details[hsia_speed] that is greater than total_charges --> 75

        list_hsia_price = dict_hsia_prices_details[f'internet_{hsia_speed}']

        if len([price for price in list_hsia_price if price >= total_charges]) > 0: 

            try: 
                hsia_price = np.min([price for price in list_hsia_price if price > total_charges])
                
                # scenario when the same price DOES EXIST in the next speed offer (e.g. if internet_500, check internet_1000 for $95 offer ==> YES): 
                hsia_speed_idx = list_hsia_speed.index(hsia_speed)
                next_hsia_speed = list_hsia_speed[hsia_speed_idx + 1]
                
                if hsia_price in dict_hsia_prices_details[f'internet_{next_hsia_speed}'] and hsia_speed == provisioned_hs_speed_numeric: 
                    list_hsia_price = dict_hsia_prices_details[f'internet_{next_hsia_speed}']
                    hsia_speed = next_hsia_speed 

            except IndexError: 
                return [None, None, None, None]

            except UnboundLocalError: 
                return [None, None, None, None]

            except ValueError: 
                return [None, None, None, None]

            # scenario when the same price DOES NOT EXIST in the next speed offer (e.g. if internet_1000, check internet_1500 for $95 offer ==> NO): 

            if hsia_price in list_hsia_price:
                plan_idx = list_hsia_price.index(hsia_price)    

            ### 4. Call the plan name by hsia_plans[provisioned_hs_speed_numeric]==250][plan_idx==4] --> "1P: Tier 3 (Internet 250)"

            hsia_plan_name = dict_hsia_plans_details[f'internet_{hsia_speed}'][plan_idx]

            return [hsia_speed, hs_max_speed_numeric, hsia_price, hsia_plan_name] 
        
        else: 

            return [None, None, None, None]

    # read the above 3 csv's (bq_irpc_digital_1p_base.csv, irpc_offer_1p_plans.csv, irpc_offer_prices.csv
    # read bq_irpc_digital_1p_base and store in df
    df_base = pd.read_csv(irpc_base_csv)
    df_plans = pd.read_csv(irpc_offer_plans_csv)
    df_prices = pd.read_csv(irpc_offer_prices_csv)
    
    # convert irpc_offer_1p_plans and irpc_offer_prices to lists and dictionaries
    # - list_hsia_speed
    # - dict_hsia_details
    list_hsia_speed, dict_hsia_plans_details = convert_df_to_list_dict(df_plans, channel)
    list_hsia_speed, dict_hsia_prices_details = convert_df_to_list_dict(df_prices, channel)
    
    offer_1_list, offer_2_list, offer_3_list = [] , [], [] 

    df_base[['hsia_speed1', 'hs_max_speed_numeric1', 'hsia_price1', 'promo_seg1']]  = df_base.apply(lambda row: pd.Series(find_casa_irpc_offers(list_hsia_speed, dict_hsia_plans_details, dict_hsia_prices_details, row, 1)), axis=1)
    df_base[['hsia_speed2', 'hs_max_speed_numeric2', 'hsia_price2', 'promo_seg2']]  = df_base.apply(lambda row: pd.Series(find_casa_irpc_offers(list_hsia_speed, dict_hsia_plans_details, dict_hsia_prices_details, row, 2)), axis=1)
    df_base[['hsia_speed3', 'hs_max_speed_numeric3', 'hsia_price3', 'promo_seg3']]  = df_base.apply(lambda row: pd.Series(find_casa_irpc_offers(list_hsia_speed, dict_hsia_plans_details, dict_hsia_prices_details, row, 3)), axis=1)
    
    df_base = df_base[['cust_id', 'bacct_num', 'fms_address_id', 'lpds_id', 'candate', 'OPTIK_TV_IND', 'HSIA_IND', 'hs_max_speed_numeric', 'provisioned_hs_speed_numeric', 
             'rpp_hsia_end_dt', 'rpp_ttv_end_dt', 'total_charges', 'promo_seg1', 'promo_seg2', 'promo_seg3']] 
    
    df_base.to_csv(save_data_path)
    
irpc_base_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/nba_offer_targeting/bq_irpc_casa_base.csv'
irpc_offer_plans_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/nba_offer_targeting/irpc_offer_1p_plans.csv'
irpc_offer_prices_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/nba_offer_targeting/irpc_offer_prices.csv'
    
offer_attachment_casa(irpc_base_csv, irpc_offer_plans_csv, irpc_offer_prices_csv, 'casa', 'gs://divg-groovyhoon-pr-d2eab4-default/uploads/irpc_casa_base_with_offers.csv')

# %% [markdown]
# ### test find_digital_irpc_offers

# %%
def convert_df_to_list_dict(df, 
                            channel: str = 'digital' # digital or casa
                            ): 

    import re
    import logging 
    from datetime import datetime

    # Change dataset / table + sp table name to version in bi-layer
    if channel == 'digital': 
        df = df
    elif channel == 'casa': 
        df = df.iloc[:4]
    else: 
        print("a parameter 'channel' can only be either 'digital' or 'casa'")

    # create list_hsia_speed = [250, 500, 1000, 1500, 3000]
    list_hsia_speed = df.columns[3:]
    
    print(list_hsia_speed)
    
    list_hsia_speed = [int(re.search(r'\d+', speed).group()) for speed in list_hsia_speed]

    # create dictionary of hsia_prices 
    # Convert DataFrame to a dictionary
    dict_hsia_details = df.to_dict(orient='list')

    return list_hsia_speed, dict_hsia_details

def find_digital_irpc_offers(list_hsia_speed: str, # list_hsia_speed = [250, 500, 1000, 1500, 3000] as of Feb 2024
                     dict_hsia_plans_details: str, # e.g. internet_250: ['1P:Regular (Internet 250)', '1P:Tier 0 (Internet 250)', '1P:Tier 1 (Internet 250)']
                     dict_hsia_prices_details: str, # e.g. internet_250: [105, 100, 95, 85, 75]
                     provisioned_hs_speed_numeric, # customer's current internet speed
                     hs_max_speed_numeric, # customer's eligible max internet speed
                     total_charges, # current internet amt
                     offer_1_ind = True 
                     ):

    import pandas as pd
    import numpy as np 

    if provisioned_hs_speed_numeric is None and hs_max_speed_numeric is None and total_charges is None: 
        return [None, None, None, None]

    ### 1. Find the smallest number in hsia_speed that is greater than provisioned_hs_speed_numeric

    # exception: if the current hsia_speed >= 150 AND hsia_speed < 500, then change the value to 499 so that it bypasses 250 
    ## Internet 150 customers should not be shown Internet 250 tier, as they are upsped in the backend to speeds of 300mbps ##
    if provisioned_hs_speed_numeric >= 150 and provisioned_hs_speed_numeric < 500: 
        provisioned_hs_speed_numeric = 499

    # store minimum hsia speed offer available greater than (or equal to) the current speed in 'hsia_speed'
    # AND 
    # minimum speed offer available where the highest offer price in that speed is greater than or equal to 'total_charges'
    
    # requirements:
        # - list_hsia_speed
        # - np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)]) --> max offer price in the internet speed
        # - compare max offer price vs total_charges 
        # - since internet_250 does not have offer tier equal to or greater than $125, we need to move on to the next speed, which is 500
        # - since internet_500 does not have offer tier equal to or greater than $125, we need to again move on to the next speed, which is 1000
        # - internet_1000 has an offer tier equal to or greater than $125, so hsia_speed = 1000
    
    if offer_1_ind == True: 
        hsia_speed = np.min([spd for spd in list_hsia_speed if spd >= provisioned_hs_speed_numeric and spd <= hs_max_speed_numeric and not pd.isna(spd)]) # --> 250
    else: 
        hsia_speed = np.min([spd for spd in list_hsia_speed if spd > provisioned_hs_speed_numeric and spd <= hs_max_speed_numeric and not pd.isna(spd)])
    
    max_offer_price = np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)])
    
    try: 
        while max_offer_price < total_charges: 
            hsia_speed_idx = list_hsia_speed.index(hsia_speed)
            hsia_speed = list_hsia_speed[hsia_speed_idx + 1]
            max_offer_price = np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)])
            
    except IndexError: 
        print("This customer is currently paying > $145, thus not eligible for any offers")

    ### 2. Find the smallest number in dict_hsia_prices_details[hsia_speed] that is greater (or equal to) than total_charges --> 75
    
    list_hsia_price = dict_hsia_prices_details[f'internet_{hsia_speed}']
    
    if len([price for price in list_hsia_price if price >= total_charges]) > 0: 
        if offer_1_ind == True: 
            hsia_price = np.min([price for price in list_hsia_price if price >= total_charges])
        else: 
            hsia_price = np.min([price for price in list_hsia_price if price > total_charges])
    
        try: 
            # scenario when the same price DOES EXIST in the next speed offer (e.g. if internet_500, check internet_1000 for $95 offer ==> YES): 
            hsia_speed_idx = list_hsia_speed.index(hsia_speed)
            next_hsia_speed = list_hsia_speed[hsia_speed_idx + 1]
            
            if hsia_price in dict_hsia_prices_details[f'internet_{next_hsia_speed}'] and hsia_speed == provisioned_hs_speed_numeric: 
                list_hsia_price = dict_hsia_prices_details[f'internet_{next_hsia_speed}']
                hsia_speed = next_hsia_speed 

        except IndexError: 
            print("The hsia_speed {hsia_speed} is the fastest internet speed available.")
            
        except UnboundLocalError: 
            print("The hsia_speed {hsia_speed} is the fastest internet speed available.")

        # scenario when the same price DOES NOT EXIST in the next speed offer (e.g. if internet_1000, check internet_1500 for $95 offer ==> NO): 
        
        if hsia_price in list_hsia_price:
            plan_idx = list_hsia_price.index(hsia_price)    

        ### 4. Call the plan name by hsia_plans[provisioned_hs_speed_numeric]==250][plan_idx==4] --> "1P: Tier 3 (Internet 250)"

        hsia_plan_name = dict_hsia_plans_details[f'internet_{hsia_speed}'][plan_idx]

        return [hsia_speed, hs_max_speed_numeric, hsia_price, hsia_plan_name] 
    
    else: 

        return [None, None, None, None]

irpc_base_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/uploads/bq_irpc_digital_1p_base.csv'
irpc_offer_plans_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/uploads/irpc_offer_1p_plans.csv'
irpc_offer_prices_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/uploads/irpc_offer_prices.csv'
    
# read the above 3 csv's (bq_irpc_digital_1p_base.csv, irpc_offer_1p_plans.csv, irpc_offer_prices.csv
# read bq_irpc_digital_1p_base and store in df
df_base = pd.read_csv(irpc_base_csv, index_col=None)
df_plans = pd.read_csv(irpc_offer_plans_csv, index_col=None)
df_prices = pd.read_csv(irpc_offer_prices_csv, index_col=None)
channel = 'digital'

# convert irpc_offer_1p_plans and irpc_offer_prices to lists and dictionaries
# - list_hsia_speed
# - dict_hsia_details
list_hsia_speed, dict_hsia_plans_details = convert_df_to_list_dict(df_plans, channel)
list_hsia_speed, dict_hsia_prices_details = convert_df_to_list_dict(df_prices, channel)

print(df_prices.head())

find_digital_irpc_offers(list_hsia_speed, dict_hsia_plans_details, dict_hsia_prices_details, 2500, 3000, 83.6367, False)

# %%
def convert_df_to_list_dict(df, 
                            channel: str = 'digital' # digital or casa
                            ): 

    import re
    import logging 
    from datetime import datetime

    # Change dataset / table + sp table name to version in bi-layer
    if channel == 'digital': 
        df = df
    elif channel == 'casa': 
        df = df.iloc[:4]
    else: 
        print("a parameter 'channel' can only be either 'digital' or 'casa'")

    # create list_hsia_speed = [250, 500, 1000, 1500, 3000]
    list_hsia_speed = df.columns[3:]
    
    print(list_hsia_speed)
    
    list_hsia_speed = [int(re.search(r'\d+', speed).group()) for speed in list_hsia_speed]

    # create dictionary of hsia_prices 
    # Convert DataFrame to a dictionary
    dict_hsia_details = df.to_dict(orient='list')

    return list_hsia_speed, dict_hsia_details

def find_casa_irpc_offers(list_hsia_speed: str, # list_hsia_speed = [250, 500, 1000, 1500, 3000] as of Feb 2024
                     dict_hsia_plans_details: str, # e.g. internet_250: ['1P:Regular (Internet 250)', '1P:Tier 0 (Internet 250)', '1P:Tier 1 (Internet 250)']
                     dict_hsia_prices_details: str, # e.g. internet_250: [105, 100, 95, 85, 75]
                     provisioned_hs_speed_numeric, # customer's current internet speed
                     hs_max_speed_numeric, # customer's eligible max internet speed
                     total_charges, # current internet amt
                     offer_3_ind = True 
                     ):
    
    import pandas as pd
    import numpy as np 
    
    if provisioned_hs_speed_numeric is None and hs_max_speed_numeric is None and total_charges is None: 
        return [None, None, None, None] 

    ### 1. Find the smallest number in hsia_speed that is greater than provisioned_hs_speed_numeric
    # exception: if the current hsia_speed >= 150 AND hsia_speed < 500, then change the value to 499 so that it bypasses 250 
    ## Internet 150 customers should not be shown Internet 250 tier, as they are upsped in the backend to speeds of 300mbps ##
    if provisioned_hs_speed_numeric >= 150 and provisioned_hs_speed_numeric < 500: 
        provisioned_hs_speed_numeric = 499

    # if offer_3_ind == True: 
    # find an L4L offer - lowest speed tier possible at equal or higher than their current pay
    # Lower speed tier than offer 1
    # Can also be in-market rack rate 

    if offer_3_ind == True: 

        try: 

            hsia_speed = np.min([spd for spd in list_hsia_speed if spd == provisioned_hs_speed_numeric and spd <= hs_max_speed_numeric and not pd.isna(spd)])

            list_hsia_price = dict_hsia_prices_details[f'internet_{hsia_speed}']

            if len([price for price in list_hsia_price if price >= total_charges]) > 0:
                hsia_price = np.min([price for price in list_hsia_price if price > total_charges])

            if hsia_price in list_hsia_price:
                plan_idx = list_hsia_price.index(hsia_price)

            hsia_plan_name = dict_hsia_plans_details[f'internet_{hsia_speed}'][plan_idx]

            return [hsia_speed, hs_max_speed_numeric, hsia_price, hsia_plan_name]

        except IndexError:
            pass

        except ValueError: 
            print("This customer already has the highest speed internet. No eligible offer found - 1")

    # store minimum hsia speed offer available greater than the current speed in 'hsia_speed'
    # AND 
    # minimum speed offer available where the highest offer price in that speed is greater than or equal to 'total_charges'

    # requirements:
        # - list_hsia_speed
        # - np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)]) --> max offer price in the internet speed
        # - compare max offer price vs total_charges 
        # - since internet_250 does not have offer tier equal to or greater than $125, we need to move on to the next speed, which is 500
        # - since internet_500 does not have offer tier equal to or greater than $125, we need to again move on to the next speed, which is 1000
        # - internet_1000 has an offer tier equal to or greater than $125, so hsia_speed = 1000

    try: 
        hsia_speed = np.min([spd for spd in list_hsia_speed if spd > provisioned_hs_speed_numeric and spd <= hs_max_speed_numeric and not pd.isna(spd)])
        max_offer_price = np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)])
        
        while max_offer_price <= total_charges: 
            hsia_speed_idx = list_hsia_speed.index(hsia_speed)
            hsia_speed = list_hsia_speed[hsia_speed_idx + 1]
            max_offer_price = np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)])

    except IndexError:
        print("This customer is currently paying > $145, thus not eligible for any offers")

    except ValueError: 
        print("This customer already has the highest speed internet. No eligible offer found - 2")
        return [None, None, None, None]

    ### 2. Find the smallest number in dict_hsia_prices_details[hsia_speed] that is greater than total_charges --> 75

    list_hsia_price = dict_hsia_prices_details[f'internet_{hsia_speed}']

    if len([price for price in list_hsia_price if price >= total_charges]) > 0: 

        try: 
            hsia_price = np.min([price for price in list_hsia_price if price > total_charges])

            # scenario when the same price DOES EXIST in the next speed offer (e.g. if internet_500, check internet_1000 for $95 offer ==> YES): 
            hsia_speed_idx = list_hsia_speed.index(hsia_speed)
            next_hsia_speed = list_hsia_speed[hsia_speed_idx + 1]

            if hsia_price in dict_hsia_prices_details[f'internet_{next_hsia_speed}'] and hsia_speed == provisioned_hs_speed_numeric: 
                list_hsia_price = dict_hsia_prices_details[f'internet_{next_hsia_speed}']
                hsia_speed = next_hsia_speed 

        except IndexError: 
            print(f"The hsia_speed {hsia_speed} is the fastest internet speed available.")

        except UnboundLocalError: 
            print(f"The hsia_speed {hsia_speed} is the fastest internet speed available.")

        except ValueError: 
            print("This customer already has the highest speed internet. No eligible offer found - 3")
            return [None, None, None, None]

        # scenario when the same price DOES NOT EXIST in the next speed offer (e.g. if internet_1000, check internet_1500 for $95 offer ==> NO): 

        if hsia_price in list_hsia_price:
            plan_idx = list_hsia_price.index(hsia_price)    

        ### 4. Call the plan name by hsia_plans[provisioned_hs_speed_numeric]==250][plan_idx==4] --> "1P: Tier 3 (Internet 250)"

        hsia_plan_name = dict_hsia_plans_details[f'internet_{hsia_speed}'][plan_idx]

        return [hsia_speed, hs_max_speed_numeric, hsia_price, hsia_plan_name] 

    else: 

        return [None, None, None, None]

import pandas as pd 
import numpy as np
    
irpc_base_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/nba_offer_targeting/bq_irpc_casa_base.csv'
irpc_offer_plans_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/nba_offer_targeting/irpc_offer_1p_plans.csv'
irpc_offer_prices_csv = 'gs://divg-groovyhoon-pr-d2eab4-default/nba_offer_targeting/irpc_offer_prices.csv'
    
# read the above 3 csv's (bq_irpc_digital_1p_base.csv, irpc_offer_1p_plans.csv, irpc_offer_prices.csv
# read bq_irpc_digital_1p_base and store in df
df_base = pd.read_csv(irpc_base_csv, index_col=None)
df_plans = pd.read_csv(irpc_offer_plans_csv, index_col=None)
df_prices = pd.read_csv(irpc_offer_prices_csv, index_col=None)
channel = 'casa'

# convert irpc_offer_1p_plans and irpc_offer_prices to lists and dictionaries
# - list_hsia_speed
# - dict_hsia_details
list_hsia_speed, dict_hsia_plans_details = convert_df_to_list_dict(df_plans, channel)
list_hsia_speed, dict_hsia_prices_details = convert_df_to_list_dict(df_prices, channel)

find_casa_irpc_offers(list_hsia_speed, dict_hsia_plans_details, dict_hsia_prices_details, 500, 1500, 110.54, True)

# %% [markdown]
# ### 5. postprocess
#
# - read one of { irpc_digital_1p_base_with_offers.csv,  irpc_digital_2p_base_with_offers.csv, irpc_casa_base_with_offers.csv }import pandas as pd
#
# - attach "Category", "Subcategory", "rpp_hsia_end_dt", "ASSMT_VALID_START_TS", "ASSMT_VALID_END_TS", "rk" to 3 offers
# - ***pay attention to the rows that have "None" values in the promo_seg1, promo_seg2, promo_seg3
# - concatenate concatenate digital_1p_reco1 + digital_1p_reco2 + digital_1p_reco3
# - write .csv to gcs (digital_1p_base_irpc_offers.csv)

# %%
import pandas as pd

def create_dict_from_dataframe(df):
    # Convert DataFrame to a list of dictionaries
    records = df.to_dict(orient='records')

    # Create the desired dictionary format
    result_dict = {record[df.columns[0]]: [record[df.columns[1]], record[df.columns[2]]] for record in records}

    return result_dict

# Example usage
data = {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]}
df = pd.DataFrame(data)

result = create_dict_from_dataframe(df)
print(result)

# %%
df_base.to_csv('gs://divg-groovyhoon-pr-d2eab4-default/uploads/irpc_digital_1p_base_with_offers.csv')

def postprocess(project_id: str
              , dataset_id: str
              , table_id: str
              , data_path: str
              , base_type: str # digital_1p, digital_2p, casa 
              ): 
    
    import pandas as pd 
    import numpy as np 

    from google.cloud import bigquery
    import logging
    from datetime import datetime
    
    df = pd.read_csv(data_path)
    
    if base_type == "digital_1p" or base_type == "casa": 
        rk = [11, 21, 31]
    elif base_type == "digital_2p" 
        rk = [10, 20, 30]
    else: 
        print("""a parameter 'base type' can only accept 'digital_1p', 'digital_2p', or 'casa' as input values""")

    def create_dict_from_df(df):
        
        # Convert DataFrame to a list of dictionaries
        records = df.to_dict(orient='records')

        # Create the desired dictionary format
        result_dict = {record[df.columns[0]]: [record[df.columns[1]], record[df.columns[2]]] for record in records}

        return result_dict

    #### For wb
    import google.oauth2.credentials
    CREDENTIALS = google.oauth2.credentials.Credentials(token)
    
    client = bigquery.Client(project=project_id, credentials=CREDENTIALS)
    job_config = bigquery.QueryJobConfig()
    
#     #### For prod 
#     client = bigquery.Client(project=project_id)
#     job_config = bigquery.QueryJobConfig()
    
    # Change dataset / table + sp table name to version in bi-layer
    query =\
        f'''
            SELECT * FROM `{project_id}.{dataset_id}.{table_id}`
        '''
    
    df_offer_details = client.query(query, job_config=job_config).to_dataframe()
    
    if 'digital' in base_type: 
        # read table `divg-groovyhoon-pr-d2eab4.nba_offer_targeting.nba_digital_offer_details` and store in df_offer_details 
        
    elif 'casa' in base_type: 
        # read table `divg-groovyhoon-pr-d2eab4.nba_offer_targeting.nba_casa_offer_details` and store in df_offer_details 
        
    dict_offer_details = create_dict_from_df(df_offer_details)
    
    ### reco1

    irpc_reco1 = df[df['promo_seg1'] !='']
    new_1p_df1 = irpc_reco1['promo_seg1'].apply(lambda x: IRPC_utilities.get_digital_details(x)).apply(pd.Series) 
    ### Or, read the second and third column of digital & casa details tables where promo_seg1 == promo_seg1.value
    irpc_reco1['promo_seg'] = new_1p_df1[0]
    irpc_reco1['offer_code'] = new_1p_df1[1]
    irpc_reco1['Category'] = 'Digital Renewal'
    irpc_reco1['Subcategory'] = 'Internet'
    irpc_reco1.loc[irpc_reco1["rpp_hsia_end_dt"].isnull(), "digital_category"] = 'Re-contracting'
    irpc_reco1.loc[irpc_reco1["rpp_hsia_end_dt"] > dt.date.today(), "digital_category"] = 'Renewal'
    irpc_reco1['ASSMT_VALID_START_TS'] = dt.datetime.now()
    irpc_reco1['ASSMT_VALID_END_TS'] = dt.datetime.now() + dt.timedelta(days=90)
    irpc_reco1['rk'] = rk[0]

    ### reco2

    irpc_reco2 = df[ df['promo_seg2'] !='']
    new_1p_df2 = irpc_reco2['promo_seg2'].apply(lambda x: get_digital_details(x)).apply(pd.Series)
    irpc_reco2['promo_seg'] = new_1p_df2[0]
    irpc_reco2['offer_code'] = new_1p_df2[1]
    irpc_reco2['Category'] = 'Digital Renewal'
    irpc_reco2['Subcategory'] = 'Internet'
    irpc_reco2.loc[irpc_reco2["rpp_hsia_end_dt"].isnull(), "digital_category"] = 'Re-contracting'
    irpc_reco2.loc[irpc_reco2["rpp_hsia_end_dt"] > dt.date.today(), "digital_category"] = 'Renewal'
    irpc_reco2['ASSMT_VALID_START_TS'] = dt.datetime.now()
    irpc_reco2['ASSMT_VALID_END_TS'] = dt.datetime.now() + dt.timedelta(days=90)
    irpc_reco2['rk'] = rk[1]

    ### reco3

    irpc_reco3 = df[ df['promo_seg3'] !='']
    new_1p_df3 = irpc_reco3['promo_seg3'].apply(lambda x: get_digital_details(x)).apply(pd.Series)
    irpc_reco3['promo_seg'] = new_1p_df3[0]
    irpc_reco3['offer_code'] = new_1p_df3[1]
    irpc_reco3['Category'] = 'Digital Renewal'
    irpc_reco3['Subcategory'] = 'Internet'
    irpc_reco3.loc[irpc_reco2["rpp_hsia_end_dt"].isnull(), "digital_category"] = 'Re-contracting'
    irpc_reco3.loc[irpc_reco2["rpp_hsia_end_dt"] > dt.date.today(), "digital_category"] = 'Renewal'
    irpc_reco3['ASSMT_VALID_START_TS'] = dt.datetime.now()
    irpc_reco3['ASSMT_VALID_END_TS'] = dt.datetime.now() + dt.timedelta(days=90)
    irpc_reco3['rk'] = rk[2]
    
    # concatenate irpc_reco1 + irpc_reco2 + irpc_reco3 
    # write .csv to gcs
    irpc_recos = pd.concat([irpc_reco1, irpc_reco2, irpc_reco3], ignore_index=True)
    irpc_recos.reset_index(inplace=True)
    
    irpc_recos.to_csv(data_path)
    
project_id = "divg-groovyhoon-pr-d2eab4"
dataset_id = "nba_offer_targeting"
table_id = "nba_digital_offer_details" 
data_path = "gs://divg-groovyhoon-pr-d2eab4-default/uploads/irpc_digital_1p_base_with_offers.csv" 
base_type = "digital_1p" 

postprocess(project_id, dataset_id, table_id, data_path, base_type)

# %% [markdown]
# ### COMPLETED & READY
#
# ### find_digital_irpc_offers()
#
# this function, { given customer's current internet speed, max speed, and hsia bill amount }, find the IRPC Renwal Offer for the customer based on the business rules

# %%
def find_digital_irpc_offers(list_hsia_speed: str, # list_hsia_speed = [250, 500, 1000, 1500, 3000] as of Feb 2024
                     dict_hsia_plans_details: str, # e.g. internet_250: ['1P:Regular (Internet 250)', '1P:Tier 0 (Internet 250)', '1P:Tier 1 (Internet 250)']
                     dict_hsia_prices_details: str, # e.g. internet_250: [105, 100, 95, 85, 75]
                     provisioned_hs_speed_numeric, # customer's current internet speed
                     hs_max_speed_numeric, # customer's eligible max internet speed
                     total_charges, # current internet amt
                     offer_1_ind = True 
                     ):

    import pandas as pd
    import numpy as np 

    if provisioned_hs_speed_numeric is None and hs_max_speed_numeric is None and total_charges is None: 
        return [None, None, None, None]

    ### 1. Find the smallest number in hsia_speed that is greater than provisioned_hs_speed_numeric

    # exception: if the current hsia_speed >= 150 AND hsia_speed < 500, then change the value to 499 so that it bypasses 250 
    ## Internet 150 customers should not be shown Internet 250 tier, as they are upsped in the backend to speeds of 300mbps ##
    if provisioned_hs_speed_numeric >= 150 and provisioned_hs_speed_numeric < 500: 
        provisioned_hs_speed_numeric = 499

    # store minimum hsia speed offer available greater than (or equal to) the current speed in 'hsia_speed'
    # AND 
    # minimum speed offer available where the highest offer price in that speed is greater than or equal to 'total_charges'
    
    # requirements:
        # - list_hsia_speed
        # - np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)]) --> max offer price in the internet speed
        # - compare max offer price vs total_charges 
        # - since internet_250 does not have offer tier equal to or greater than $125, we need to move on to the next speed, which is 500
        # - since internet_500 does not have offer tier equal to or greater than $125, we need to again move on to the next speed, which is 1000
        # - internet_1000 has an offer tier equal to or greater than $125, so hsia_speed = 1000
    
    if offer_1_ind == True: 
        hsia_speed = np.min([spd for spd in list_hsia_speed if spd >= provisioned_hs_speed_numeric and spd <= hs_max_speed_numeric and not pd.isna(spd)]) # --> 250
    else: 
        hsia_speed = np.min([spd for spd in list_hsia_speed if spd > provisioned_hs_speed_numeric and spd <= hs_max_speed_numeric and not pd.isna(spd)])
    
    max_offer_price = np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)])
    
    try: 
        while max_offer_price < total_charges: 
            hsia_speed_idx = list_hsia_speed.index(hsia_speed)
            hsia_speed = list_hsia_speed[hsia_speed_idx + 1]
            max_offer_price = np.max([spd for spd in dict_hsia_prices_details[f'internet_{hsia_speed}'] if not pd.isna(spd)])
            
    except IndexError: 
        print("This customer is currently paying > $145, thus not eligible for any offers")

    ### 2. Find the smallest number in dict_hsia_prices_details[hsia_speed] that is greater (or equal to) than total_charges --> 75
    
    list_hsia_price = dict_hsia_prices_details[f'internet_{hsia_speed}']
    
    if len([price for price in list_hsia_price if price >= total_charges]) > 0: 
        if offer_1_ind == True: 
            hsia_price = np.min([price for price in list_hsia_price if price >= total_charges])
        else: 
            hsia_price = np.min([price for price in list_hsia_price if price > total_charges])
    
        try: 
            # scenario when the same price DOES EXIST in the next speed offer (e.g. if internet_500, check internet_1000 for $95 offer ==> YES): 
            hsia_speed_idx = list_hsia_speed.index(hsia_speed)
            next_hsia_speed = list_hsia_speed[hsia_speed_idx + 1]
            
            if hsia_price in dict_hsia_prices_details[f'internet_{next_hsia_speed}'] and hsia_speed == provisioned_hs_speed_numeric: 
                list_hsia_price = dict_hsia_prices_details[f'internet_{next_hsia_speed}']
                hsia_speed = next_hsia_speed 

        except IndexError: 
            print("The hsia_speed {hsia_speed} is the fastest internet speed available.")
            
        except UnboundLocalError: 
            print("The hsia_speed {hsia_speed} is the fastest internet speed available.")

        # scenario when the same price DOES NOT EXIST in the next speed offer (e.g. if internet_1000, check internet_1500 for $95 offer ==> NO): 
        
        if hsia_price in list_hsia_price:
            plan_idx = list_hsia_price.index(hsia_price)    

        ### 4. Call the plan name by hsia_plans[provisioned_hs_speed_numeric]==250][plan_idx==4] --> "1P: Tier 3 (Internet 250)"

        hsia_plan_name = dict_hsia_plans_details[f'internet_{hsia_speed}'][plan_idx]

        return [hsia_speed, hs_max_speed_numeric, hsia_price, hsia_plan_name] 
    
    else: 

        return [None, None, None, None]

# %% [markdown]
# ### Create a function that reads nba_offer_targeting.irpc_offer_plans and creates the following lists and dictionaries
#
#
# # list of available hsia speeds in IRPC offers
# list_hsia_speed = [250, 500, 1000, 1500, 3000]
#
# # dictionary of hsia prices
# dict_hsia_price = {250: [105, 100, 95, 85, 75],
#                    500: [115, 110, 105, 95, 85],
#                    1000: [125, 120, 115, 105, 95, 85],
#                    1500: [135, 130, 125, 115, 105],
#                    3000: [145]}
#
# hsia_plans_1p = {250: ["1P: Regular (Internet 250)", "1P: Tier 0 (Internet 250)", "1P: Tier 1 (Internet 250)", "1P: Tier 2 (Internet 250)", "1P: Tier 3 (Internet 250)"],
#                  500: ["1P: Regular (Internet 500)", "1P: Tier 0 (Internet 500)", "1P: Tier 1 (Internet 500)", "1P: Tier 2 (Internet 500)", "1P: Tier 3 (Internet 500)"],
#                  1000: ["1P: Regular (Gigabit)", "1P: Tier 0 (Gigabit)", "1P: Tier 1 (Gigabit)", "1P: Tier 2 (Gigabit)", "1P: Tier 3 (Gigabit)", "1P: Tier 4 (Gigabit)"],
#                  1500: ["1P: Regular (1.5 Gigabit, XGS)", "1P: Tier 0 (1.5 Gigabit, XGS)", "1P: Tier 1 (1.5 Gigabit, XGS)", "1P: Tier 2 (1.5 Gigabit, XGS)", "1P: Tier 3 (1.5 Gigabit, XGS)"],
#                  3000: ["1P: Regular (3 Gigabit)"]}
#
# hsia_plans_2p = {250: ["2P: Regular (Internet 250)", "2P: Tier 0 (Internet 250)", "2P: Tier 1 (Internet 250)", "2P: Tier 2 (Internet 250)", "2P: Tier 3 (Internet 250)"],
#                  500: ["2P: Regular (Internet 500)", "2P: Tier 0 (Internet 500)", "2P: Tier 1 (Internet 500)", "2P: Tier 2 (Internet 500)", "2P: Tier 3 (Internet 500)"],
#                  1000: ["2P: Regular (Gigabit)", "2P: Tier 0 (Gigabit)", "2P: Tier 1 (Gigabit)", "2P: Tier 2 (Gigabit)", "2P: Tier 3 (Gigabit)", "2P: Tier 4 (Gigabit)"],
#                  1500: ["2P: Regular (1.5 Gigabit, XGS)", "2P: Tier 0 (1.5 Gigabit, XGS)", "2P: Tier 1 (1.5 Gigabit, XGS)", "2P: Tier 2 (1.5 Gigabit, XGS)", "2P: Tier 3 (1.5 Gigabit, XGS)"],
#                  3000: ["2P: Regular (3 Gigabit)"]}

# %% [markdown]
# ### bq_irpc_offers
#
# this function is used to convert the following tables into a list and a dictionary.
#
# - divg-groovyhoon-pr-d2eab4.nba_offer_targeting.irpc_offer_prices
# - divg-groovyhoon-pr-d2eab4.nba_offer_targeting.irpc_offer_1p_plans
# - divg-groovyhoon-pr-d2eab4.nba_offer_targeting.irpc_offer_2p_plans

# %%
project_id = "divg-groovyhoon-pr-d2eab4"
dataset_id = "nba_offer_targeting" 
table_id = "irpc_offer_prices"
region = "northamerica-northeast1"

def bq_irpc_offers(project_id: str
              , dataset_id: str
              , table_id: str
              , region: str
              , channel: str = 'digital' # digital or casa
              ): 
 
    import re
    from google.cloud import bigquery
    import logging 
    from datetime import datetime

    #### this code block is only for a personal workbench 

    import google.oauth2.credentials
    token = !gcloud auth print-access-token
    token_str = token[0]

    #### the end

    #### For wb
    import google.oauth2.credentials
    CREDENTIALS = google.oauth2.credentials.Credentials(token_str)

    client = bigquery.Client(project=project_id, credentials=CREDENTIALS)
    job_config = bigquery.QueryJobConfig()

    #     #### For prod 
    #     client = bigquery.Client(project=project_id)
    #     job_config = bigquery.QueryJobConfig()

    # Change dataset / table + sp table name to version in bi-layer
    if channel == 'digital': 
        query =\
            f'''
                SELECT *
                FROM `{project_id}.{dataset_id}.{table_id}` 
            '''
    elif channel == 'casa': 
        query =\
            f'''
                SELECT *
                FROM `{project_id}.{dataset_id}.{table_id}` 
                WHERE index_num < 4 -- Only Regular, Tier 0, Tier 1, and Tier 2 Offers are available in casa
            '''
    else: 
        print("a parameter 'channel' can only be either 'digital' or 'casa'""")

    df = client.query(query, job_config=job_config).to_dataframe()
    
    # create list_hsia_speed = [250, 500, 1000, 1500, 3000] 
    list_hsia_speed = df.columns[3:]
    list_hsia_speed = [int(re.search(r'\d+', speed).group()) for speed in list_hsia_speed]

    # create dictionary of hsia_prices 
    # Convert DataFrame to a dictionary
    dict_hsia_details = df.to_dict(orient='list')

    return list_hsia_speed, dict_hsia_details

# %%
project_id = "divg-groovyhoon-pr-d2eab4"
dataset_id = "nba_offer_targeting" 
table_id = "irpc_offer_prices"
region = "northamerica-northeast1"

list_0, dict_0 = bq_irpc_offers(project_id, dataset_id, table_id, region, 'casa')

project_id = "divg-groovyhoon-pr-d2eab4"
dataset_id = "nba_offer_targeting" 
table_id = "irpc_offer_prices"
region = "northamerica-northeast1"

list_1, dict_1 = bq_irpc_offers(project_id, dataset_id, table_id, region, 'digital')

project_id = "divg-groovyhoon-pr-d2eab4"
dataset_id = "nba_offer_targeting" 
table_id = "irpc_offer_1p_plans"
region = "northamerica-northeast1"

list_2, dict_2 = bq_irpc_offers(project_id, dataset_id, table_id, region, 'digital')

project_id = "divg-groovyhoon-pr-d2eab4"
dataset_id = "nba_offer_targeting" 
table_id = "irpc_offer_2p_plans"
region = "northamerica-northeast1"

list_3, dict_3 = bq_irpc_offers(project_id, dataset_id, table_id, region, 'digital')

print(list_0)
formatted_output = '\n'.join(f'{key}: {value}' for key, value in dict_0.items())
print(formatted_output)
print(" ")

print(list_1)
formatted_output = '\n'.join(f'{key}: {value}' for key, value in dict_1.items())
print(formatted_output)
print(" ")

print(list_2)
formatted_output = '\n'.join(f'{key}: {value}' for key, value in dict_2.items())
print(formatted_output)
print(" ")

print(list_3)
formatted_output = '\n'.join(f'{key}: {value}' for key, value in dict_3.items())
print(formatted_output)
print(" ")

# %%
import re

# create list_hsia_speed = [250, 500, 1000, 1500, 3000] 
list_hsia_speed = df.columns[3:]
list_hsia_speed = [int(re.search(r'\d+', speed).group()) for speed in list_hsia_speed]

# create dictionary of hsia_prices 
# Convert DataFrame to a dictionary
dict_hsia_details = df.to_dict(orient='list')

print(dict_hsia_details)

# %%
from google.cloud import bigquery
import logging 
from datetime import datetime

#### this code block is only for a personal workbench 

import google.oauth2.credentials
token = !gcloud auth print-access-token
token_str = token[0]

project_id = "divg-groovyhoon-pr-d2eab4"

#### the end

#### For wb
import google.oauth2.credentials
CREDENTIALS = google.oauth2.credentials.Credentials(token_str)

client = bigquery.Client(project=project_id, credentials=CREDENTIALS)
job_config = bigquery.QueryJobConfig()

#     #### For prod 
#     client = bigquery.Client(project=project_id)
#     job_config = bigquery.QueryJobConfig()

# Change dataset / table + sp table name to version in bi-layer
query =\
    f'''
        SELECT * FROM `divg-groovyhoon-pr-d2eab4.nba_offer_targeting.irpc_offer_2p_plans`
    '''

df = client.query(query, job_config=job_config).to_dataframe()

df.head(10)

# %%
from google.cloud import bigquery
import logging 
from datetime import datetime

#### this code block is only for a personal workbench 

import google.oauth2.credentials
token = !gcloud auth print-access-token
token_str = token[0]

project_id = "divg-groovyhoon-pr-d2eab4"

#### the end

#### For wb
import google.oauth2.credentials
CREDENTIALS = google.oauth2.credentials.Credentials(token_str)

client = bigquery.Client(project=project_id, credentials=CREDENTIALS)
job_config = bigquery.QueryJobConfig()

#     #### For prod 
#     client = bigquery.Client(project=project_id)
#     job_config = bigquery.QueryJobConfig()

# Change dataset / table + sp table name to version in bi-layer
query =\
    f'''
        SELECT * FROM `divg-groovyhoon-pr-d2eab4.nba_offer_targeting.bq_irpc_digital_1p_base` WHERE total_charges > 75 ORDER BY RAND() LIMIT 20
    '''

df = client.query(query, job_config=job_config).to_dataframe()

df.head(10)

# %%
import pandas as pd
import numpy as np 

for idx, row in df.iterrows():

    # list of available hsia speeds in IRPC offers
    list_hsia_speed = [250, 500, 1000, 1500, 3000]
    
    # dictionary of hsia prices 
    dict_hsia_price = {250: [105, 100, 95, 85, 75], \
                       500: [115, 110, 105, 95, 85], \
                       1000: [125, 120, 115, 105, 95, 85], \
                       1500: [135, 130, 125, 115, 105], \
                       3000: [145]}

    hsia_plans_1p = {250: ["1P: Regular (Internet 250)", "1P: Tier 0 (Internet 250)", "1P: Tier 1 (Internet 250)", "1P: Tier 2 (Internet 250)", "1P: Tier 3 (Internet 250)"],
                     500: ["1P: Regular (Internet 500)", "1P: Tier 0 (Internet 500)", "1P: Tier 1 (Internet 500)", "1P: Tier 2 (Internet 500)", "1P: Tier 3 (Internet 500)"],
                     1000: ["1P: Regular (Gigabit)", "1P: Tier 0 (Gigabit)", "1P: Tier 1 (Gigabit)", "1P: Tier 2 (Gigabit)", "1P: Tier 3 (Gigabit)", "1P: Tier 4 (Gigabit)"],
                     1500: ["1P: Regular (1.5 Gigabit, XGS)", "1P: Tier 0 (1.5 Gigabit, XGS)", "1P: Tier 1 (1.5 Gigabit, XGS)", "1P: Tier 2 (1.5 Gigabit, XGS)", "1P: Tier 3 (1.5 Gigabit, XGS)"],
                     3000: ["1P: Regular (3 Gigabit)"]}
        
    hsia_plans_2p = {250: ["2P: Regular (Internet 250)", "2P: Tier 0 (Internet 250)", "2P: Tier 1 (Internet 250)", "2P: Tier 2 (Internet 250)", "2P: Tier 3 (Internet 250)"],
                     500: ["2P: Regular (Internet 500)", "2P: Tier 0 (Internet 500)", "2P: Tier 1 (Internet 500)", "2P: Tier 2 (Internet 500)", "2P: Tier 3 (Internet 500)"],
                     1000: ["2P: Regular (Gigabit)", "2P: Tier 0 (Gigabit)", "2P: Tier 1 (Gigabit)", "2P: Tier 2 (Gigabit)", "2P: Tier 3 (Gigabit)", "2P: Tier 4 (Gigabit)"],
                     1500: ["2P: Regular (1.5 Gigabit, XGS)", "2P: Tier 0 (1.5 Gigabit, XGS)", "2P: Tier 1 (1.5 Gigabit, XGS)", "2P: Tier 2 (1.5 Gigabit, XGS)", "2P: Tier 3 (1.5 Gigabit, XGS)"],
                     3000: ["2P: Regular (3 Gigabit)"]}
    
    # store data in the variables
    provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges = row['provisioned_hs_speed_numeric'], row['hs_max_speed_numeric'], row['total_charges']
    
    ### 1. Find the smallest number in hsia_speed that is greater than provisioned_hs_speed_numeric

    # exception: if the current hsia_speed >= 150 AND hsia_speed < 500, then change the value to 499 so that it bypasses 250 
    ## Internet 150 customers should not be shown Internet 250 tier, as they are upsped in the backend to speeds of 300mbps ##
    if provisioned_hs_speed_numeric >= 150 and provisioned_hs_speed_numeric < 500: 
        provisioned_hs_speed_numeric = 499
    
    # store minimum hsia speed available greater than the current speed in 'hsia_speed'
    hsia_speed = np.min([spd for spd in list_hsia_speed if spd >= provisioned_hs_speed_numeric])
    
    ### 2. Find the hsia_speed in list_hsia_speed that the customer is eligible for
    
    list_elig_hsia_speed = [spd for spd in list_hsia_speed if spd >= hsia_speed and spd <= hs_max_speed_numeric] 

    ### 3. Find the smallest number in dict_hsia_price[hsia_speed] that is greater than total_charges --> 753
    print(f'current internet speed {hsia_speed}: {dict_hsia_price[hsia_speed]}')
    
    list_hsia_price = dict_hsia_price[hsia_speed]
    
    if len([price for price in list_hsia_price if price > total_charges]) > 0: 
        hsia_price = np.min([price for price in list_hsia_price if price >= total_charges])

        if hsia_price in list_hsia_price:
            plan_idx = list_hsia_price.index(hsia_price)    

        ### 4. Call the plan name by hsia_plans[provisioned_hs_speed_numeric]==250][plan_idx==4] --> "1P: Tier 3 (Internet 250)"

        hsia_plan_name_1p = hsia_plans_1p[hsia_speed][plan_idx]

        print(f'currently paying: {total_charges}')
        print(f'list_hsia_price: {list_hsia_price}') 
        print(f'hsia_price: {hsia_price}')
        print(f'plan_idx: {plan_idx}')
        print(f'hsia_plan_name_1p: {hsia_plan_name_1p}') 
        print(" ") 
        
        total_charges = None
        list_hsia_price = None
        hsia_price = None
        plan_idx = None
        hsia_plan_name_1p = None

    else: 
        print(f'total_charges: {total_charges}')
        print(f'list_hsia_price: {list_hsia_price}') 
        print("no IRPC offer is available for this customer")
        print(" ") 

        total_charges = None
        list_hsia_price = None
        hsia_price = None
        plan_idx = None
        hsia_plan_name_1p = None

# %%
import pandas as pd
import numpy as np 

def digital_1p_promo_segments(provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges, offer_1_ind = True):

    # list of available hsia speeds in IRPC offers
    list_hsia_speed = [250, 500, 1000, 1500, 3000]
    
    # dictionary of hsia prices 
    dict_hsia_price = {250: [105, 100, 95, 85, 75],
                       500: [115, 110, 105, 95, 85],
                       1000: [125, 120, 115, 105, 95, 85],
                       1500: [135, 130, 125, 115, 105],
                       3000: [145]}

    hsia_plans_1p = {250: ["1P: Regular (Internet 250)", "1P: Tier 0 (Internet 250)", "1P: Tier 1 (Internet 250)", "1P: Tier 2 (Internet 250)", "1P: Tier 3 (Internet 250)"],
                     500: ["1P: Regular (Internet 500)", "1P: Tier 0 (Internet 500)", "1P: Tier 1 (Internet 500)", "1P: Tier 2 (Internet 500)", "1P: Tier 3 (Internet 500)"],
                     1000: ["1P: Regular (Gigabit)", "1P: Tier 0 (Gigabit)", "1P: Tier 1 (Gigabit)", "1P: Tier 2 (Gigabit)", "1P: Tier 3 (Gigabit)", "1P: Tier 4 (Gigabit)"],
                     1500: ["1P: Regular (1.5 Gigabit, XGS)", "1P: Tier 0 (1.5 Gigabit, XGS)", "1P: Tier 1 (1.5 Gigabit, XGS)", "1P: Tier 2 (1.5 Gigabit, XGS)", "1P: Tier 3 (1.5 Gigabit, XGS)"],
                     3000: ["1P: Regular (3 Gigabit)"]}
        
    hsia_plans_2p = {250: ["2P: Regular (Internet 250)", "2P: Tier 0 (Internet 250)", "2P: Tier 1 (Internet 250)", "2P: Tier 2 (Internet 250)", "2P: Tier 3 (Internet 250)"],
                     500: ["2P: Regular (Internet 500)", "2P: Tier 0 (Internet 500)", "2P: Tier 1 (Internet 500)", "2P: Tier 2 (Internet 500)", "2P: Tier 3 (Internet 500)"],
                     1000: ["2P: Regular (Gigabit)", "2P: Tier 0 (Gigabit)", "2P: Tier 1 (Gigabit)", "2P: Tier 2 (Gigabit)", "2P: Tier 3 (Gigabit)", "2P: Tier 4 (Gigabit)"],
                     1500: ["2P: Regular (1.5 Gigabit, XGS)", "2P: Tier 0 (1.5 Gigabit, XGS)", "2P: Tier 1 (1.5 Gigabit, XGS)", "2P: Tier 2 (1.5 Gigabit, XGS)", "2P: Tier 3 (1.5 Gigabit, XGS)"],
                     3000: ["2P: Regular (3 Gigabit)"]}
    
    if provisioned_hs_speed_numeric is None and  hs_max_speed_numeric is None and  total_charges is None: 
        return [None, None, None, None]
    
    ### 1. Find the smallest number in hsia_speed that is greater than provisioned_hs_speed_numeric

    # exception: if the current hsia_speed >= 150 AND hsia_speed < 500, then change the value to 499 so that it bypasses 250 
    ## Internet 150 customers should not be shown Internet 250 tier, as they are upsped in the backend to speeds of 300mbps ##
    if provisioned_hs_speed_numeric >= 150 and provisioned_hs_speed_numeric < 500: 
        provisioned_hs_speed_numeric = 499
    
    # store minimum hsia speed available greater than the current speed in 'hsia_speed'
    if offer_1_ind == True: 
        hsia_speed = np.min([spd for spd in list_hsia_speed if spd >= provisioned_hs_speed_numeric])
    else: 
        hsia_speed = np.min([spd for spd in list_hsia_speed if spd > provisioned_hs_speed_numeric])
    
    ### 2. Find the hsia_speed in list_hsia_speed that the customer is eligible for
    
    list_elig_hsia_speed = [spd for spd in list_hsia_speed if spd >= hsia_speed and spd <= hs_max_speed_numeric] 
    
    ### 3. Find the smallest number in dict_hsia_price[hsia_speed] that is greater than total_charges --> 753
    # print(f'offer internet speed {hsia_speed}: {dict_hsia_price[hsia_speed]}')
    
    list_hsia_price = dict_hsia_price[hsia_speed]
    
    if len([price for price in list_hsia_price if price > total_charges]) > 0: 
        if offer_1_ind == True: 
            hsia_price = np.min([price for price in list_hsia_price if price >= total_charges])
        else: 
            hsia_price = np.min([price for price in list_hsia_price if price > total_charges])

        if hsia_price in list_hsia_price:
            plan_idx = list_hsia_price.index(hsia_price)    

        ### 4. Call the plan name by hsia_plans[provisioned_hs_speed_numeric]==250][plan_idx==4] --> "1P: Tier 3 (Internet 250)"

        hsia_plan_name_1p = hsia_plans_1p[hsia_speed][plan_idx]

        return [hsia_speed, hs_max_speed_numeric, hsia_price, hsia_plan_name_1p] 
        
    else: 
          
        return [None, None, None, None]

# %%
print(digital_1p_promo_segments(1000, 3000, 90, True))

# %%
print(digital_1p_promo_segments(500, 3000, 85, False))

# %%
print(digital_1p_promo_segments(1000, 3000, 95, False))

# %%
print(digital_1p_promo_segments(None, None, None, False))

# %%
offer_1_list, offer_2_list, offer_3_list = [] , [], [] 

for idx, row in df.iterrows():
    provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges = row['provisioned_hs_speed_numeric'], row['hs_max_speed_numeric'], row['total_charges']
    
    # print(digital_1p_promo_segments(provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges, True) )
    
    offer_1_hsia_speed, offer_1_hs_max_speed_numeric, offer_1_hsia_price, offer_1_hsia_plan_name_1p = digital_1p_promo_segments(provisioned_hs_speed_numeric, hs_max_speed_numeric, total_charges, True) 
    offer_2_hsia_speed, offer_2_hs_max_speed_numeric, offer_2_hsia_price, offer_2_hsia_plan_name_1p = digital_1p_promo_segments(offer_1_hsia_speed, offer_1_hs_max_speed_numeric, offer_1_hsia_price, False) 
    offer_3_hsia_speed, offer_3_hs_max_speed_numeric, offer_3_hsia_price, offer_3_hsia_plan_name_1p = digital_1p_promo_segments(offer_2_hsia_speed, offer_2_hs_max_speed_numeric, offer_2_hsia_price, False) 
        
    offer_1_list.append(offer_1_hsia_plan_name_1p)
    offer_2_list.append(offer_2_hsia_plan_name_1p)
    offer_3_list.append(offer_3_hsia_plan_name_1p)
    
df['promo_seg1'] = offer_1_list
df['promo_seg2'] = offer_2_list
df['promo_seg3'] = offer_3_list

df.head(10)

# %%
# ### Digital 1P reco1

digital_1p_reco1 = df[df['promo_seg1'] !='']

new_1p_df1 = digital_1p_reco1['promo_seg1'].apply(lambda x: IRPC_utilities.get_digital_details(x)).apply(pd.Series) 
### Or, read the second and third column of digital & casa details tables where promo_seg1 == promo_seg1.value

digital_1p_reco1['promo_seg'] = new_1p_df1[0]
digital_1p_reco1['offer_code'] = new_1p_df1[1]
digital_1p_reco1['Category'] = 'Digital Renewal'
digital_1p_reco1['Subcategory'] = 'Internet'
digital_1p_reco1.loc[digital_1p_reco1["rpp_hsia_end_dt"].isnull(), "digital_category"] = 'Re-contracting'
digital_1p_reco1.loc[digital_1p_reco1["rpp_hsia_end_dt"] > dt.date.today(), "digital_category"] = 'Renewal'
digital_1p_reco1['ASSMT_VALID_START_TS'] = dt.datetime.now()
digital_1p_reco1['ASSMT_VALID_END_TS'] = dt.datetime.now() + dt.timedelta(days=90)
digital_1p_reco1['rk'] = 11

# ### Digital 1P reco2

digital_1p_reco2 = df[ df['promo_seg2'] !='']
new_1p_df2 = digital_1p_reco2['promo_seg2'].apply(lambda x: get_digital_details(x)).apply(pd.Series)
digital_1p_reco2['promo_seg'] = new_1p_df2[0]
digital_1p_reco2['offer_code'] = new_1p_df2[1]
digital_1p_reco2['Category'] = 'Digital Renewal'
digital_1p_reco2['Subcategory'] = 'Internet'
digital_1p_reco2.loc[digital_1p_reco2["rpp_hsia_end_dt"].isnull(), "digital_category"] = 'Re-contracting'
digital_1p_reco2.loc[digital_1p_reco2["rpp_hsia_end_dt"] > dt.date.today(), "digital_category"] = 'Renewal'
digital_1p_reco2['ASSMT_VALID_START_TS'] = dt.datetime.now()
digital_1p_reco2['ASSMT_VALID_END_TS'] = dt.datetime.now() + dt.timedelta(days=90)
digital_1p_reco2['rk'] = 21

# ### Digital 1P reco3

digital_1p_reco3 = df[ df['promo_seg3'] !='']
new_1p_df3 = digital_1p_reco3['promo_seg3'].apply(lambda x: get_digital_details(x)).apply(pd.Series)
digital_1p_reco3['promo_seg'] = new_1p_df3[0]
digital_1p_reco3['offer_code'] = new_1p_df3[1]
digital_1p_reco3['Category'] = 'Digital Renewal'
digital_1p_reco3['Subcategory'] = 'Internet'
digital_1p_reco3.loc[digital_1p_reco2["rpp_hsia_end_dt"].isnull(), "digital_category"] = 'Re-contracting'
digital_1p_reco3.loc[digital_1p_reco2["rpp_hsia_end_dt"] > dt.date.today(), "digital_category"] = 'Renewal'
digital_1p_reco3['ASSMT_VALID_START_TS'] = dt.datetime.now()
digital_1p_reco3['ASSMT_VALID_END_TS'] = dt.datetime.now() + dt.timedelta(days=90)
digital_1p_reco3['rk'] = 31

# concatenate digital_1p_reco1 + digital_1p_reco2 + digital_1p_reco3 
# write .csv to gcs
