# %%
#### import global modules
import os
import sys
import pandas as pd
import numpy as np
from pathlib import Path
from yaml import safe_load
import google.oauth2.credentials
from google.cloud import bigquery
import gc

# Set global vars
pth_project = Path(os.getcwd().split('notebooks')[0])
pth_data = pth_project / 'data'
pth_queries = pth_project / 'core' / 'queries'
pth_creds = pth_project / 'conf' / 'local' / 'project_config.yaml'
sys.path.insert(0, str(pth_project))
d_project_config = safe_load(pth_creds.open())
# d_params = safe_load((pth_project / 'core' / 'parameters' / 'common.yaml').open())['data_extract']

# import local modules
from core.utils.gcp import connect_bq_services
# from core.etl.extract import extract_bq_data, extract_pr_codes, format_conv_df, filter_convs

# Connect to google services
bq_client = connect_bq_services(d_project_config['gcp-project-name'])
pd.options.display.max_rows = 100

# %%
def extract_bq_data(bq_client, sql=None, pth_query=None):
    if sql is not None:
        df = bq_client.query(sql).to_dataframe()
    elif pth_query is not None:
        sql = pth_query.read_text()
        df = bq_client.query(sql).to_dataframe()
    else:
        raise ValueError('`sql` or `pth_query` should be set')  
    return df

# %%
ADC_ADT_mapping=pd.read_csv('ADC_ADT_mapping.csv',low_memory=False)

# %%
ADC_ADT_mapping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306650 entries, 0 to 306649
# Data columns (total 64 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   ImportationDate                 306650 non-null  object
#  1   CustomerId                      306650 non-null  int64
#  2   DealerCustomerId                125825 non-null  object
#  3   JoinDate                        306650 non-null  object
#  4   StreetAddress1                  306649 non-null  object
#  5   StreetAddress2                  7827 non-null    object
#  6   City                            306649 non-null  object
#  7   State                           306246 non-null  object
#  8   ZipCode                         306649 non-null  object
#  9   FirstName                       306627 non-null  object
#  10  LastName                        306636 non-null  object
#  11  CompanyName                     1071 non-null    object
#  12  ModemSerial                     306646 non-null  object
#  13  ModemVersion                    306650 non-null  float64
#  14  ModemTwoWayCapable              306650 non-null  bool
#  15  NetworkId                       306650 non-null  int64
#  16  PanelVersionId                  306650 non-null  int64
#  17  DealerBranchId                  306650 non-null  int64
#  18  DealerId                        306650 non-null  int64
#  19  OriginalDealerId                306650 non-null  int64
#  20  PackageId                       306650 non-null  int64
#  21  Addons                          306650 non-null  object
#  22  CentralStationForwardingOption  306650 non-null  int64
#  23  CSEventGroups                   306650 non-null  object
#  24  PrimaryEmail                    306650 non-null  object
#  25  PrimaryPhone                    306650 non-null  object
#  26  CreatingRep                     306493 non-null  object
#  27  DateBegin                       306650 non-null  object
#  28  DateEnd                         306650 non-null  object
#  29  install_date                    141816 non-null  object
#  30  active_date                     306126 non-null  object
#  31  AccountNumber                   306649 non-null  object
#  32  AccountPrefix                   306012 non-null  object
#  33  test                            37899 non-null   object
#  34  AlarmCom_cs_no                  306649 non-null  object
#  35  branch_no                       306650 non-null  float64
#  36  site_no                         306650 non-null  float64
#  37  sitetype_id                     306650 non-null  object
#  38  Branch Description              306044 non-null  object
#  39  JoinMonth                       306650 non-null  object
#  40  EmailVerified                   154692 non-null  float64
#  41  HasAGeodevice                   154692 non-null  float64
#  42  MobileContact                   154692 non-null  float64
#  43  HasRules                        154692 non-null  float64
#  44  HasArmingReminders              154692 non-null  float64
#  45  HasAHomeAutomationDevice        154692 non-null  float64
#  46  CurrentActiveAccounts           154692 non-null  float64
#  47  BestPraticeValue                154692 non-null  float64
#  48  LastLogin                       294101 non-null  object
#  49  LastMobileLogin                 294101 non-null  object
#  50  AvgAppLoginsPerDay              159994 non-null  float64
#  51  AvgWebLoginsPerDay              159994 non-null  float64
#  52  AvgVoiceLoginsPerDay            159994 non-null  float64
#  53  AvgAllLoginsPerDay              159994 non-null  float64
#  54  Last7DaysLogin                  0 non-null       float64
#  55  LastMonthLogin                  0 non-null       float64
#  56  TotalImageSensors               2083 non-null    float64
#  57  TotalCaptured                   2083 non-null    float64
#  58  TotalUploaded                   2083 non-null    float64
#  59  LastUpload                      2083 non-null    object
#  60  TotalPeekedIn                   2083 non-null    float64
#  61  LastPeekInTime                  2083 non-null    object
#  62  rn                              306650 non-null  int64
#  63  ADT_customer_flag               306650 non-null  int64
# dtypes: bool(1), float64(21), int64(10), object(32)
# memory usage: 147.7+ MB

# %%
ADC_ADT_mapping['sitetype_id']=ADC_ADT_mapping['sitetype_id'].str.strip()

# %%
ADC_ADT_mapping['sitetype_id'].value_counts()
# Out:
# R    306650
# Name: sitetype_id, dtype: int64

# %%
# ADC_ADT_mapping['CustomerId_1']=ADC_ADT_mapping['CustomerId'].astype('object')

# %%
ADC_ADT_mapping.head()
# Out:
#            ImportationDate  CustomerId DealerCustomerId             JoinDate  \
# 0  2019-09-13 00:00:00.000     7606283              NaN  2019-07-31 13:13:03
# 1  2022-08-13 00:00:00.000    14161472              NaN  2022-07-29 08:52:33
# 2  2022-09-23 00:00:00.000    14583072              NaN  2022-09-21 16:11:17
# 3  2020-12-24 00:00:00.000    10231254              NaN  2020-12-23 09:14:10
# 4  2021-01-14 00:00:00.000    10475995              NaN  2021-01-13 09:02:28
#
#            StreetAddress1 StreetAddress2             City State ZipCode  \
# 0     5510 MILLE ILES DES            NaN  ST FRANCOIS LVL    QC  H7L1K5
# 1      122 GILLES LABARRE            NaN      CHATEAUGUAY    QC  J6J5T4
# 2         429 WOODLEA AVE            NaN       MONT-ROYAL    QC  H3P1R7
# 3      460 SOMMET BLEU DU            NaN         ST ADELE    QC  J0R1L0
# 4  1775 RENE LAENNEC BLVD            NaN            LAVAL    QC  H7M5C8
#
#                    FirstName  ... Last7DaysLogin LastMonthLogin  \
# 0                    ADAN MR  ...            NaN            NaN
# 1  STEPHANE/PICHETTE,NATHALI  ...            NaN            NaN
# 2                      SARDI  ...            NaN            NaN
# 3                    MAURICE  ...            NaN            NaN
# 4                       JOSE  ...            NaN            NaN
#
#   TotalImageSensors  TotalCaptured  TotalUploaded  LastUpload  TotalPeekedIn  \
# 0               NaN            NaN            NaN         NaN            NaN
# 1               NaN            NaN            NaN         NaN            NaN
# 2               NaN            NaN            NaN         NaN            NaN
# 3               NaN            NaN            NaN         NaN            NaN
# 4               NaN            NaN            NaN         NaN            NaN
#
#    LastPeekInTime  rn  ADT_customer_flag
# 0             NaN   1                  1
# 1             NaN   1                  1
# 2             NaN   1                  1
# 3             NaN   1                  1
# 4             NaN   1                  1
#
# [5 rows x 64 columns]

# %%
Customer_Details_Query='''

SELECT customer_id,dealer_customer_id,primary_login_id,dealer_name,join_date,account_type_name,customer_type_name,primary_email,primary_phone,last_updt_ts
FROM `cio-datahub-enterprise-pr-183a.src_adc.bq_customer_account_details` 
where dealer_name='ADT by TELUS'
--and account_type_name!='Standalone'
--and customer_type_name='Customer'
QUALIFY ROW_NUMBER() OVER (PARTITION BY customer_id ORDER BY last_updt_ts DESC) = 1
order by dealer_name,join_date,customer_id


'''

# %%
Customer_DF=extract_bq_data(bq_client, sql=Customer_Details_Query)

# %%
Customer_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279038 entries, 0 to 279037
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   customer_id         279038 non-null  Int64
#  1   dealer_customer_id  279038 non-null  object
#  2   primary_login_id    279038 non-null  Int64
#  3   dealer_name         279038 non-null  object
#  4   join_date           279038 non-null  datetime64[ns, UTC]
#  5   account_type_name   279038 non-null  object
#  6   customer_type_name  279038 non-null  object
#  7   primary_email       279038 non-null  object
#  8   primary_phone       279038 non-null  object
#  9   last_updt_ts        279038 non-null  datetime64[ns, UTC]
# dtypes: Int64(2), datetime64[ns, UTC](2), object(6)
# memory usage: 21.8+ MB

# %%
Customer_DF['dealer_name'].value_counts()
# Out:
# ADT by TELUS    279038
# Name: dealer_name, dtype: int64

# %%
ADC_ADT_mapping['ADT_customer_flag']=1

# %%
Merge_data=Customer_DF.merge(ADC_ADT_mapping[ADC_ADT_mapping['sitetype_id']=='R'],how='inner',left_on='customer_id',right_on='CustomerId')

# %%
Merge_data['ADT_customer_flag'].sum()
# Out:
# 218151

# %%
Merge_data['customer_type_name'].value_counts()
# Out:
# Customer         218039
# Commitment           60
# From Recycle         41
# Demo - Normal        11
# Name: customer_type_name, dtype: int64

# %%
Merge_data['dealer_name'].value_counts()
# Out:
# ADT by TELUS    218151
# Name: dealer_name, dtype: int64

# %%
Merge_data.head()
# Out:
#    customer_id dealer_customer_id  primary_login_id   dealer_name  \
# 0       287850                               306491  ADT by TELUS
# 1       292877                               311600  ADT by TELUS
# 2       359052                               382402  ADT by TELUS
# 3       361396           50001346            384875  ADT by TELUS
# 4       361475                               384957  ADT by TELUS
#
#                   join_date account_type_name customer_type_name  \
# 0 2009-07-08 10:46:52+00:00   Security System           Customer
# 1 2009-07-16 00:34:52+00:00   Security System           Customer
# 2 2010-03-12 18:12:23+00:00   Security System           Customer
# 3 2010-03-18 11:18:44+00:00   Security System           Customer
# 4 2010-03-18 13:21:35+00:00   Security System           Customer
#
#                                        primary_email primary_phone  \
# 0   AeFd5ZDQfT+2dlYTQE+NVn9VE9Q+PP6Jz99bl40h0FllVg==  +14034619748
# 1  AYM0XZ60owqcI4xfVSe4qu/D79HXcWIz03BAhCe4DwvAvE...  +14035565543
# 2  AXEModsEPR/On9XxBpHhTOsK4/7JD1zj2pQ1KuslUwk7EH...  +17806557428
# 3   AfweuuQerY2xv70GPiAMA4NyzuShjslGEwWmcqdjO/sDFQ==  +17804463443
# 4  AVv7q8XdOTYLZMlyJe3bzqe+CmymXcYqvfpmS2pm1TvBaL...  +14166533767
#
#                       last_updt_ts  ... Last7DaysLogin  LastMonthLogin  \
# 0 2022-11-17 11:20:18.335370+00:00  ...            NaN             NaN
# 1 2022-11-17 11:20:18.335370+00:00  ...            NaN             NaN
# 2 2022-11-16 11:26:59.835886+00:00  ...            NaN             NaN
# 3 2022-10-28 11:19:58.768721+00:00  ...            NaN             NaN
# 4 2022-10-21 11:27:36.706033+00:00  ...            NaN             NaN
#
#   TotalImageSensors TotalCaptured TotalUploaded LastUpload TotalPeekedIn  \
# 0               NaN           NaN           NaN        NaN           NaN
# 1               NaN           NaN           NaN        NaN           NaN
# 2               NaN           NaN           NaN        NaN           NaN
# 3               NaN           NaN           NaN        NaN           NaN
# 4               NaN           NaN           NaN        NaN           NaN
#
#   LastPeekInTime rn ADT_customer_flag
# 0            NaN  1                 1
# 1            NaN  1                 1
# 2            NaN  1                 1
# 3            NaN  1                 1
# 4            NaN  1                 1
#
# [5 rows x 74 columns]

# %%
Merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 218151 entries, 0 to 218150
# Data columns (total 74 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   customer_id                     218151 non-null  Int64
#  1   dealer_customer_id              218151 non-null  object
#  2   primary_login_id                218151 non-null  Int64
#  3   dealer_name                     218151 non-null  object
#  4   join_date                       218151 non-null  datetime64[ns, UTC]
#  5   account_type_name               218151 non-null  object
#  6   customer_type_name              218151 non-null  object
#  7   primary_email                   218151 non-null  object
#  8   primary_phone                   218151 non-null  object
#  9   last_updt_ts                    218151 non-null  datetime64[ns, UTC]
#  10  ImportationDate                 218151 non-null  object
#  11  CustomerId                      218151 non-null  int64
#  12  DealerCustomerId                74301 non-null   object
#  13  JoinDate                        218151 non-null  object
#  14  StreetAddress1                  218151 non-null  object
#  15  StreetAddress2                  4038 non-null    object
#  16  City                            218151 non-null  object
#  17  State                           217752 non-null  object
#  18  ZipCode                         218151 non-null  object
#  19  FirstName                       218139 non-null  object
#  20  LastName                        218143 non-null  object
#  21  CompanyName                     621 non-null     object
#  22  ModemSerial                     218150 non-null  object
#  23  ModemVersion                    218151 non-null  float64
#  24  ModemTwoWayCapable              218151 non-null  bool
#  25  NetworkId                       218151 non-null  int64
#  26  PanelVersionId                  218151 non-null  int64
#  27  DealerBranchId                  218151 non-null  int64
#  28  DealerId                        218151 non-null  int64
#  29  OriginalDealerId                218151 non-null  int64
#  30  PackageId                       218151 non-null  int64
#  31  Addons                          218151 non-null  object
#  32  CentralStationForwardingOption  218151 non-null  int64
#  33  CSEventGroups                   218151 non-null  object
#  34  PrimaryEmail                    218151 non-null  object
#  35  PrimaryPhone                    218151 non-null  object
#  36  CreatingRep                     218073 non-null  object
#  37  DateBegin                       218151 non-null  object
#  38  DateEnd                         218151 non-null  object
#  39  install_date                    93384 non-null   object
#  40  active_date                     218105 non-null  object
#  41  AccountNumber                   218150 non-null  object
#  42  AccountPrefix                   217526 non-null  object
#  43  test                            28209 non-null   object
#  44  AlarmCom_cs_no                  218150 non-null  object
#  45  branch_no                       218151 non-null  float64
#  46  site_no                         218151 non-null  float64
#  47  sitetype_id                     218151 non-null  object
#  48  Branch Description              217658 non-null  object
#  49  JoinMonth                       218151 non-null  object
#  50  EmailVerified                   108112 non-null  float64
#  51  HasAGeodevice                   108112 non-null  float64
#  52  MobileContact                   108112 non-null  float64
#  53  HasRules                        108112 non-null  float64
#  54  HasArmingReminders              108112 non-null  float64
#  55  HasAHomeAutomationDevice        108112 non-null  float64
#  56  CurrentActiveAccounts           108112 non-null  float64
#  57  BestPraticeValue                108112 non-null  float64
#  58  LastLogin                       218148 non-null  object
#  59  LastMobileLogin                 218148 non-null  object
#  60  AvgAppLoginsPerDay              135847 non-null  float64
#  61  AvgWebLoginsPerDay              135847 non-null  float64
#  62  AvgVoiceLoginsPerDay            135847 non-null  float64
#  63  AvgAllLoginsPerDay              135847 non-null  float64
#  64  Last7DaysLogin                  0 non-null       float64
#  65  LastMonthLogin                  0 non-null       float64
#  66  TotalImageSensors               773 non-null     float64
#  67  TotalCaptured                   773 non-null     float64
#  68  TotalUploaded                   773 non-null     float64
#  69  LastUpload                      773 non-null     object
#  70  TotalPeekedIn                   773 non-null     float64
#  71  LastPeekInTime                  773 non-null     object
#  72  rn                              218151 non-null  int64
#  73  ADT_customer_flag               218151 non-null  int64
# dtypes: Int64(2), bool(1), datetime64[ns, UTC](2), float64(21), int64(10), object(38)
# memory usage: 123.8+ MB

# %%
rep_chars = ' |\|-|:|/'

Merge_data.columns = Merge_data.columns.str.replace(rep_chars, '_')
# Out:
# /tmp/ipykernel_16114/1618702354.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   Merge_data.columns = Merge_data.columns.str.replace(rep_chars, '_')

# %%
Merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 218151 entries, 0 to 218150
# Data columns (total 74 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   customer_id                     218151 non-null  Int64
#  1   dealer_customer_id              218151 non-null  object
#  2   primary_login_id                218151 non-null  Int64
#  3   dealer_name                     218151 non-null  object
#  4   join_date                       218151 non-null  datetime64[ns, UTC]
#  5   account_type_name               218151 non-null  object
#  6   customer_type_name              218151 non-null  object
#  7   primary_email                   218151 non-null  object
#  8   primary_phone                   218151 non-null  object
#  9   last_updt_ts                    218151 non-null  datetime64[ns, UTC]
#  10  ImportationDate                 218151 non-null  object
#  11  CustomerId                      218151 non-null  int64
#  12  DealerCustomerId                74301 non-null   object
#  13  JoinDate                        218151 non-null  object
#  14  StreetAddress1                  218151 non-null  object
#  15  StreetAddress2                  4038 non-null    object
#  16  City                            218151 non-null  object
#  17  State                           217752 non-null  object
#  18  ZipCode                         218151 non-null  object
#  19  FirstName                       218139 non-null  object
#  20  LastName                        218143 non-null  object
#  21  CompanyName                     621 non-null     object
#  22  ModemSerial                     218150 non-null  object
#  23  ModemVersion                    218151 non-null  float64
#  24  ModemTwoWayCapable              218151 non-null  bool
#  25  NetworkId                       218151 non-null  int64
#  26  PanelVersionId                  218151 non-null  int64
#  27  DealerBranchId                  218151 non-null  int64
#  28  DealerId                        218151 non-null  int64
#  29  OriginalDealerId                218151 non-null  int64
#  30  PackageId                       218151 non-null  int64
#  31  Addons                          218151 non-null  object
#  32  CentralStationForwardingOption  218151 non-null  int64
#  33  CSEventGroups                   218151 non-null  object
#  34  PrimaryEmail                    218151 non-null  object
#  35  PrimaryPhone                    218151 non-null  object
#  36  CreatingRep                     218073 non-null  object
#  37  DateBegin                       218151 non-null  object
#  38  DateEnd                         218151 non-null  object
#  39  install_date                    93384 non-null   object
#  40  active_date                     218105 non-null  object
#  41  AccountNumber                   218150 non-null  object
#  42  AccountPrefix                   217526 non-null  object
#  43  test                            28209 non-null   object
#  44  AlarmCom_cs_no                  218150 non-null  object
#  45  branch_no                       218151 non-null  float64
#  46  site_no                         218151 non-null  float64
#  47  sitetype_id                     218151 non-null  object
#  48  Branch_Description              217658 non-null  object
#  49  JoinMonth                       218151 non-null  object
#  50  EmailVerified                   108112 non-null  float64
#  51  HasAGeodevice                   108112 non-null  float64
#  52  MobileContact                   108112 non-null  float64
#  53  HasRules                        108112 non-null  float64
#  54  HasArmingReminders              108112 non-null  float64
#  55  HasAHomeAutomationDevice        108112 non-null  float64
#  56  CurrentActiveAccounts           108112 non-null  float64
#  57  BestPraticeValue                108112 non-null  float64
#  58  LastLogin                       218148 non-null  object
#  59  LastMobileLogin                 218148 non-null  object
#  60  AvgAppLoginsPerDay              135847 non-null  float64
#  61  AvgWebLoginsPerDay              135847 non-null  float64
#  62  AvgVoiceLoginsPerDay            135847 non-null  float64
#  63  AvgAllLoginsPerDay              135847 non-null  float64
#  64  Last7DaysLogin                  0 non-null       float64
#  65  LastMonthLogin                  0 non-null       float64
#  66  TotalImageSensors               773 non-null     float64
#  67  TotalCaptured                   773 non-null     float64
#  68  TotalUploaded                   773 non-null     float64
#  69  LastUpload                      773 non-null     object
#  70  TotalPeekedIn                   773 non-null     float64
#  71  LastPeekInTime                  773 non-null     object
#  72  rn                              218151 non-null  int64
#  73  ADT_customer_flag               218151 non-null  int64
# dtypes: Int64(2), bool(1), datetime64[ns, UTC](2), float64(21), int64(10), object(38)
# memory usage: 123.8+ MB

# %%
config= bigquery.job.LoadJobConfig()

# config._properties['timePartitioning'] = {'field': 'Month_Year'}
config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE

Table_BQ = 'ADC_updated.ADC_ADT_mapping'

bq_table_instance= bq_client.load_table_from_dataframe(Merge_data, Table_BQ,job_config=config)
