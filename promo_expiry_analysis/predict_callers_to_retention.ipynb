# %% [markdown]
# ## Predict callers to retention

# %% [markdown]
# ### read csv

# %%
#import libraries
import os
import re
import time
import google
from google.oauth2 import credentials
from google.oauth2 import service_account
from google.oauth2.service_account import Credentials
from datetime import date
from datetime import timedelta
from dateutil.relativedelta import relativedelta
import pandas as pd
import numpy as np
import pickle
from google.cloud import storage
from google.cloud import bigquery
from sklearn.model_selection import train_test_split

# build model
import xgboost as xgb
from sklearn.metrics import roc_auc_score

file_bucket = 'divg-josh-pr-d1cc3a-default' 
folder_name = 'promo_expiry_analysis'

df = pd.read_csv('gs://{}/{}/data.csv'.format(file_bucket, folder_name))

# %% [markdown]
# ### preprocess
#
# - Tenure Group: cat
# - PROV: cat
# - Pcount: cat
# - Price Plan Grouping: cat
# - Technology Group: cat
# - demographics: cat
# - CampaignFlag: cat
# - TOTALCalls: remove

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112460 entries, 0 to 112459
# Data columns (total 55 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   BAN                                    112460 non-null  int64
#  1   Tenure Group                           112460 non-null  object
#  2   PROV                                   112460 non-null  object
#  3   Pcount                                 112460 non-null  object
#  4   Product Count                          112460 non-null  int64
#  5   HasHSIA                                112460 non-null  int64
#  6   HasHP                                  112460 non-null  int64
#  7   HasTV                                  112460 non-null  int64
#  8   HasSMHM                                112460 non-null  int64
#  9   productMix_product_mix_all             112460 non-null  int64
#  10  productMix_hsic_count                  112460 non-null  int64
#  11  productMix_sing_count                  112460 non-null  int64
#  12  productMix_ttv_count                   112460 non-null  int64
#  13  productMix_shs_count                   112460 non-null  int64
#  14  productMix_new_hsic_ind                112460 non-null  int64
#  15  productMix_new_sing_ind                112460 non-null  int64
#  16  productMix_new_ttv_ind                 112460 non-null  int64
#  17  productMix_new_smhm_ind                112460 non-null  int64
#  18  Price Plan Grouping                    112460 non-null  object
#  19  Technology Group                       112460 non-null  object
#  20  TOTAL_CHARGE                           112460 non-null  float64
#  21  HSIA_CHARGE                            112460 non-null  float64
#  22  HP_CHARGE                              112460 non-null  float64
#  23  TV_CHARGE                              112460 non-null  float64
#  24  SMHM_CHARGE                            112460 non-null  float64
#  25  tot_disc_amt                           112460 non-null  float64
#  26  hsic_disc_amt                          112460 non-null  float64
#  27  sing_disc_amt                          112460 non-null  float64
#  28  ttv_disc_amt                           112460 non-null  float64
#  29  smhm_disc_amt                          112460 non-null  float64
#  30  TOTAL_CHARGE_NO_DISC                   112460 non-null  float64
#  31  HSIC_CHARGE_NO_DISC                    112460 non-null  float64
#  32  SING_CHARGE_NO_DISC                    112460 non-null  float64
#  33  TTV_CHARGE_NO_DISC                     112460 non-null  float64
#  34  SMHS_CHARGE_NO_DISC                    112460 non-null  float64
#  35  total_disc_pct                         112460 non-null  float64
#  36  hsic_disc_pct                          112460 non-null  float64
#  37  sing_disc_pct                          112460 non-null  float64
#  38  ttv_disc_pct                           112460 non-null  float64
#  39  smhm_disc_pct                          112460 non-null  float64
#  40  hsiaUsage_hs_tot_gb_avg                112460 non-null  float64
#  41  demographics_demo_avg_income           112460 non-null  float64
#  42  troubleTickets_number_tickets          112460 non-null  int64
#  43  troubleTickets_ticket_hsia_affected    112460 non-null  int64
#  44  troubleTickets_ticket_tv_affected      112460 non-null  int64
#  45  troubleTickets_ticket_phone_affected   112460 non-null  int64
#  46  callCentre_avg_talk_time_30_days_hsic  112460 non-null  float64
#  47  callCentre_avg_talk_time_30_days_sing  112460 non-null  float64
#  48  callCentre_avg_talk_time_30_days_ttv   112460 non-null  float64
#  49  callCentre_avg_talk_time_30_days_smhm  112460 non-null  int64
#  50  infra_num_srvc_typ_copper_sum          112460 non-null  int64
#  51  infra_num_srvc_typ_gpon_sum            112460 non-null  int64
#  52  demographics                           112460 non-null  object
#  53  CampaignFlag                           112460 non-null  object
#  54  target                                 112460 non-null  int64
# dtypes: float64(25), int64(23), object(7)
# memory usage: 47.2+ MB

# %%
df.columns
# Out:
# Index(['BAN', 'Tenure Group', 'PROV', 'Pcount', 'Product Count', 'HasHSIA',
#        'HasHP', 'HasTV', 'HasSMHM', 'productMix_product_mix_all',
#        'productMix_hsic_count', 'productMix_sing_count',
#        'productMix_ttv_count', 'productMix_shs_count',
#        'productMix_new_hsic_ind', 'productMix_new_sing_ind',
#        'productMix_new_ttv_ind', 'productMix_new_smhm_ind',
#        'Price Plan Grouping', 'Technology Group', 'TOTAL_CHARGE',
#        'HSIA_CHARGE', 'HP_CHARGE', 'TV_CHARGE', 'SMHM_CHARGE', 'tot_disc_amt',
#        'hsic_disc_amt', 'sing_disc_amt', 'ttv_disc_amt', 'smhm_disc_amt',
#        'TOTAL_CHARGE_NO_DISC', 'HSIC_CHARGE_NO_DISC', 'SING_CHARGE_NO_DISC',
#        'TTV_CHARGE_NO_DISC', 'SMHS_CHARGE_NO_DISC', 'total_disc_pct',
#        'hsic_disc_pct', 'sing_disc_pct', 'ttv_disc_pct', 'smhm_disc_pct',
#        'hsiaUsage_hs_tot_gb_avg', 'demographics_demo_avg_income',
#        'troubleTickets_number_tickets', 'troubleTickets_ticket_hsia_affected',
#        'troubleTickets_ticket_tv_affected',
#        'troubleTickets_ticket_phone_affected',
#        'callCentre_avg_talk_time_30_days_hsic',
#        'callCentre_avg_talk_time_30_days_sing',
#        'callCentre_avg_talk_time_30_days_ttv',
#        'callCentre_avg_talk_time_30_days_smhm',
#        'infra_num_srvc_typ_copper_sum', 'infra_num_srvc_typ_gpon_sum',
#        'demographics', 'CampaignFlag', 'target'],
#       dtype='object')

# %%
cols_to_dummy = ['Tenure Group', 'PROV', 'Pcount', 'Price Plan Grouping', 'Technology Group', 'demographics', 'CampaignFlag']

for col in cols_to_dummy: 

    # Create dummy variables for the Country column
    df = pd.get_dummies(df, columns=[col], drop_first=True, prefix=None, dtype="int64")

# reorder the df columns so that 'target' comes last
df_processed = df[[c for c in df if c not in ['target']] 
       + ['target']]

df_processed.columns = df_processed.columns.str.replace('<', 'less_than_')
df_processed.columns = df_processed.columns.str.replace(' ', '_')

df_processed.head()
# Out:
#          BAN  Product_Count  HasHSIA  HasHP  HasTV  HasSMHM  \
# 0  603512534              2        1      0      1        0
# 1  225975121              2        1      1      0        0
# 2  234048777              3        1      1      1        0
# 3  604553605              2        1      0      1        0
# 4  604260803              1        1      0      0        0
#
#    productMix_product_mix_all  productMix_hsic_count  productMix_sing_count  \
# 0                           2                      1                      0
# 1                           2                      1                      1
# 2                           4                      1                      1
# 3                           2                      1                      0
# 4                           1                      1                      0
#
#    productMix_ttv_count  ...  Price_Plan_Grouping_Other  \
# 0                     1  ...                          0
# 1                     0  ...                          0
# 2                     1  ...                          0
# 3                     1  ...                          0
# 4                     0  ...                          0
#
#    Technology_Group_Fibre  demographics_rural_family  demographics_unassigned  \
# 0                       0                          0                        0
# 1                       1                          0                        0
# 2                       1                          0                        0
# 3                       1                          0                        0
# 4                       1                          0                        0
#
#    demographics_urban  demographics_urban_family  demographics_urban_young  \
# 0                   0                          1                         0
# 1                   0                          1                         0
# 2                   0                          1                         0
# 3                   0                          1                         0
# 4                   0                          1                         0
#
#    CampaignFlag_Reached  CampaignFlag_Targeted  target
# 0                     0                      0       1
# 1                     0                      0       1
# 2                     1                      0       1
# 3                     0                      0       1
# 4                     1                      0       0
#
# [5 rows x 66 columns]

# %%
df_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112460 entries, 0 to 112459
# Data columns (total 66 columns):
#  #   Column                                          Non-Null Count   Dtype
# ---  ------                                          --------------   -----
#  0   BAN                                             112460 non-null  int64
#  1   Product_Count                                   112460 non-null  int64
#  2   HasHSIA                                         112460 non-null  int64
#  3   HasHP                                           112460 non-null  int64
#  4   HasTV                                           112460 non-null  int64
#  5   HasSMHM                                         112460 non-null  int64
#  6   productMix_product_mix_all                      112460 non-null  int64
#  7   productMix_hsic_count                           112460 non-null  int64
#  8   productMix_sing_count                           112460 non-null  int64
#  9   productMix_ttv_count                            112460 non-null  int64
#  10  productMix_shs_count                            112460 non-null  int64
#  11  productMix_new_hsic_ind                         112460 non-null  int64
#  12  productMix_new_sing_ind                         112460 non-null  int64
#  13  productMix_new_ttv_ind                          112460 non-null  int64
#  14  productMix_new_smhm_ind                         112460 non-null  int64
#  15  TOTAL_CHARGE                                    112460 non-null  float64
#  16  HSIA_CHARGE                                     112460 non-null  float64
#  17  HP_CHARGE                                       112460 non-null  float64
#  18  TV_CHARGE                                       112460 non-null  float64
#  19  SMHM_CHARGE                                     112460 non-null  float64
#  20  tot_disc_amt                                    112460 non-null  float64
#  21  hsic_disc_amt                                   112460 non-null  float64
#  22  sing_disc_amt                                   112460 non-null  float64
#  23  ttv_disc_amt                                    112460 non-null  float64
#  24  smhm_disc_amt                                   112460 non-null  float64
#  25  TOTAL_CHARGE_NO_DISC                            112460 non-null  float64
#  26  HSIC_CHARGE_NO_DISC                             112460 non-null  float64
#  27  SING_CHARGE_NO_DISC                             112460 non-null  float64
#  28  TTV_CHARGE_NO_DISC                              112460 non-null  float64
#  29  SMHS_CHARGE_NO_DISC                             112460 non-null  float64
#  30  total_disc_pct                                  112460 non-null  float64
#  31  hsic_disc_pct                                   112460 non-null  float64
#  32  sing_disc_pct                                   112460 non-null  float64
#  33  ttv_disc_pct                                    112460 non-null  float64
#  34  smhm_disc_pct                                   112460 non-null  float64
#  35  hsiaUsage_hs_tot_gb_avg                         112460 non-null  float64
#  36  demographics_demo_avg_income                    112460 non-null  float64
#  37  troubleTickets_number_tickets                   112460 non-null  int64
#  38  troubleTickets_ticket_hsia_affected             112460 non-null  int64
#  39  troubleTickets_ticket_tv_affected               112460 non-null  int64
#  40  troubleTickets_ticket_phone_affected            112460 non-null  int64
#  41  callCentre_avg_talk_time_30_days_hsic           112460 non-null  float64
#  42  callCentre_avg_talk_time_30_days_sing           112460 non-null  float64
#  43  callCentre_avg_talk_time_30_days_ttv            112460 non-null  float64
#  44  callCentre_avg_talk_time_30_days_smhm           112460 non-null  int64
#  45  infra_num_srvc_typ_copper_sum                   112460 non-null  int64
#  46  infra_num_srvc_typ_gpon_sum                     112460 non-null  int64
#  47  Tenure_Group_5-6Y                               112460 non-null  int64
#  48  Tenure_Group_7+Y                                112460 non-null  int64
#  49  Tenure_Group_less_than_2Y                       112460 non-null  int64
#  50  PROV_BC                                         112460 non-null  int64
#  51  Pcount_2P                                       112460 non-null  int64
#  52  Pcount_3P                                       112460 non-null  int64
#  53  Pcount_4P                                       112460 non-null  int64
#  54  Price_Plan_Grouping_Internet/Optik_250-1GB      112460 non-null  int64
#  55  Price_Plan_Grouping_Internet/Optik_Under_250MB  112460 non-null  int64
#  56  Price_Plan_Grouping_Other                       112460 non-null  int64
#  57  Technology_Group_Fibre                          112460 non-null  int64
#  58  demographics_rural_family                       112460 non-null  int64
#  59  demographics_unassigned                         112460 non-null  int64
#  60  demographics_urban                              112460 non-null  int64
#  61  demographics_urban_family                       112460 non-null  int64
#  62  demographics_urban_young                        112460 non-null  int64
#  63  CampaignFlag_Reached                            112460 non-null  int64
#  64  CampaignFlag_Targeted                           112460 non-null  int64
#  65  target                                          112460 non-null  int64
# dtypes: float64(25), int64(41)
# memory usage: 56.6 MB

# %% [markdown]
# ### register lift function

# %%
def get_lift(prob, y_test, q):
    result = pd.DataFrame(columns=['Prob', 'CallToRetention'])
    result['Prob'] = prob
    result['CallToRetention'] = y_test
    result['Decile'] = pd.qcut(result['Prob'], q, labels=[i for i in range(q, 0, -1)])
    add = pd.DataFrame(result.groupby('Decile')['CallToRetention'].mean()).reset_index()
    add.columns = ['Decile', 'avg_real_call_rate']
    add2 = pd.DataFrame(result.groupby('Decile')['CallToRetention'].count()).reset_index()
    add2.columns = ['Decile', 'ban_count']
    result = result.merge(add, on='Decile', how='left')
    result = result.merge(add2, on='Decile', how='left')
    result.sort_values('Decile', ascending=True, inplace=True)
    lg = pd.DataFrame(result.groupby('Decile')['Prob'].mean()).reset_index()
    lg.columns = ['Decile', 'avg_model_pred_call_rate']
    lg.sort_values('Decile', ascending=False, inplace=True)
    lg['avg_call_rate_total'] = result['CallToRetention'].mean()
    lg = lg.merge(add, on='Decile', how='left')
    lg = lg.merge(add2, on='Decile', how='left')
    lg['lift'] = lg['avg_real_call_rate'] / lg['avg_call_rate_total']

    return lg

# %% [markdown]
# ### set X_train, X_test, y_train, y_test

# %%
features = [col for col in df_processed.columns if col not in ["BAN", "target"]]

X, y = df_processed[[col for col in df_processed.columns if col != "target"]], df_processed["target"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=None, shuffle=True)

ban_train = X_train['BAN']
X_train = X_train[features]
y_train = np.squeeze(y_train.values)

ban_test = X_test['BAN']
X_test = X_test[features]
y_test = np.squeeze(y_test.values)

# %% [markdown]
# ### set up xgb and train the model

# %%
# build model and fit in training data
import xgboost as xgb
from sklearn.metrics import roc_auc_score

xgb_model = xgb.XGBClassifier(
    learning_rate=0.01,
    n_estimators=80,
    max_depth=8,
    min_child_weight=1,
    gamma=0,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='binary:logistic',
    nthread=4,
    scale_pos_weight=1
    # seed=27
)

xgb_model.fit(X_train, y_train)
print('xgb training done')

# %% [markdown]
# ### make predictions on X_train

# %%
from sklearn.preprocessing import normalize

#predictions on X_test
pred_prb = xgb_model.predict_proba(X_train, ntree_limit=xgb_model.best_iteration)[:, 1]
pred_prb = np.array(normalize([pred_prb]))[0]

#join ban_test, X_test, y_test and pred_prb and print to csv
#CHECK THE SIZE OF EACH COMPONENT BEFORE JOINING
q=10
df_ban_train = ban_train.to_frame()
df_train_exp = df_ban_train.join(X_train) 
df_train_exp['y_test'] = y_train
df_train_exp['y_pred_proba'] = pred_prb
df_train_exp['y_pred'] = (df_train_exp['y_pred_proba'] > 0.5).astype(int)
df_train_exp['decile'] = pd.qcut(df_train_exp['y_pred_proba'], q, labels=[i for i in range(q, 0, -1)])

lg = get_lift(pred_prb, y_train, q)

lg

# %% [markdown]
# ### make predictions on X_test

# %%
from sklearn.preprocessing import normalize

#predictions on X_test
pred_prb = xgb_model.predict_proba(X_test, ntree_limit=xgb_model.best_iteration)[:, 1]
pred_prb = np.array(normalize([pred_prb]))[0]

#join ban_test, X_test, y_test and pred_prb and print to csv
#CHECK THE SIZE OF EACH COMPONENT BEFORE JOINING
q=10
df_ban_test = ban_test.to_frame()
df_test_exp = df_ban_test.join(X_test) 
df_test_exp['y_test'] = y_test
df_test_exp['y_pred_proba'] = pred_prb
df_test_exp['y_pred'] = (df_test_exp['y_pred_proba'] > 0.5).astype(int)
df_test_exp['decile'] = pd.qcut(df_test_exp['y_pred_proba'], q, labels=[i for i in range(q, 0, -1)])

lg = get_lift(pred_prb, y_test, q)

lg

# %% [markdown]
# ### get lift
